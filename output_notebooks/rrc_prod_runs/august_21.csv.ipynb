# %%
import pandas as pd
import datetime as dt

pd.options.display.max_columns=1000
pd.options.display.max_rows = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %run configs.ipynb

# %%
# parameter cell
file_name = 'oct_21.csv'

# %%
# Parameters
file_name = "august_21.csv"

# %% [markdown]
# # RRC Prod

# %% [markdown]
# ## Ingest

# %%
production = pd.read_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', header = 5)

# %%
production.head()
# Out:
#   Multiple Reports Lease Type  District  RRC Identifier    Field Name  \
# 0              NaN        Oil       8.0         32907.0  ARMER (TUBB)
# 1              NaN        Oil       8.0         20550.0  ARMER (6350)
# 2              NaN        Oil       8.0         45314.0  ARMER (6350)
# 3              NaN        Oil       8.0         48393.0  ARMER (6350)
# 4              NaN        Oil       8.0         49425.0  ARMER (6350)
#
#                     Lease Name Gas Well ID Lease Total  Commingle Permit No.  \
# 0   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN                7024.0
# 1  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN                7024.0
# 2               RAYDEN MCCAMEY         NaN         NaN                   NaN
# 3                   LANDLUBBER         NaN         NaN                8026.0
# 4                 6 POUNDER NE         NaN         NaN                8026.0
#
#   On Hand Beginning of Month Production Volume  Code On Hand End of Month  \
# 0                        222         38    NaN   NaN                  260
# 1                         39          0    NaN   NaN                   39
# 2                        183         89    NaN   NaN                  272
# 3                      1,882      8,215  8,165   0.0                1,932
# 4                        485      1,253  1,344   0.0                  394
#
#   Formation Production Volume.1  Code.1
# 0                    0      NaN     NaN
# 1                    0      NaN     NaN
# 2                2,064    2,064     2.0
# 3               28,894   28,894     2.0
# 4                6,773    6,773     2.0

# %% [markdown]
# ## Transform RRC

# %% [markdown]
# ### Filter to District

# %%
#converting data field to string to handle varying schema interpreations 
#(certain months field will be interpreted as float and string depending sample rows pandas uses

production = production.loc[production['District'].astype(str).isin(['8.0', '08', '8'])]

# %%
production
# Out:
#     Multiple Reports Lease Type  District  RRC Identifier          Field Name  \
# 0                NaN        Oil       8.0         32907.0        ARMER (TUBB)
# 1                NaN        Oil       8.0         20550.0        ARMER (6350)
# 2                NaN        Oil       8.0         45314.0        ARMER (6350)
# 3                NaN        Oil       8.0         48393.0        ARMER (6350)
# 4                NaN        Oil       8.0         49425.0        ARMER (6350)
# ..               ...        ...       ...             ...                 ...
# 462              NaN        Gas       8.0        147187.0  WADDELL (GRAYBURG)
# 463              NaN        Gas       8.0        190864.0  WADDELL (GRAYBURG)
# 464              NaN        Gas       8.0        190926.0  WADDELL (GRAYBURG)
# 465              NaN        Gas       8.0        205775.0  WADDELL (GRAYBURG)
# 466              NaN        Oil       8.0         20361.0   -Y-, SOUTH (TUBB)
#
#                       Lease Name Gas Well ID Lease Total  \
# 0     MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1    MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2                 RAYDEN MCCAMEY         NaN         NaN
# 3                     LANDLUBBER         NaN         NaN
# 4                   6 POUNDER NE         NaN         NaN
# ..                           ...         ...         ...
# 462                WADDELL, W.N.       859           NaN
# 463                WADDELL, W.N.       890           NaN
# 464                WADDELL, W.N.       293           NaN
# 465               WADDELL, W. N.      1200           NaN
# 466  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production Volume  Code  \
# 0                  7024.0                        222         38    NaN   NaN
# 1                  7024.0                         39          0    NaN   NaN
# 2                     NaN                        183         89    NaN   NaN
# 3                  8026.0                      1,882      8,215  8,165   0.0
# 4                  8026.0                        485      1,253  1,344   0.0
# ..                    ...                        ...        ...    ...   ...
# 462                8988.0                          7         16     16   1.0
# 463                8988.0                          0          0    NaN   NaN
# 464                3501.0                          7         34     27   1.0
# 465                8092.0                          7         34     27   1.0
# 466                3803.0                          0          0    NaN   NaN
#
#     On Hand End of Month Formation Production Volume.1  Code.1
# 0                    260                    0      NaN     NaN
# 1                     39                    0      NaN     NaN
# 2                    272                2,064    2,064     2.0
# 3                  1,932               28,894   28,894     2.0
# 4                    394                6,773    6,773     2.0
# ..                   ...                  ...      ...     ...
# 462                    7                  800      800     2.0
# 463                    0                    0      NaN     NaN
# 464                   14                  649      649     2.0
# 465                   14                  891      891     2.0
# 466                    0                    0      NaN     NaN
#
# [464 rows x 17 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 464 entries, 0 to 466
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Multiple Reports            92 non-null     object
#  1   Lease Type                  409 non-null    object
#  2   District                    464 non-null    float64
#  3   RRC Identifier              464 non-null    float64
#  4   Field Name                  464 non-null    object
#  5   Lease Name                  464 non-null    object
#  6   Gas Well ID                 232 non-null    object
#  7   Lease Total                 14 non-null     object
#  8   Commingle Permit No.        274 non-null    float64
#  9   On Hand Beginning of Month  414 non-null    object
#  10  Production                  464 non-null    object
#  11  Volume                      196 non-null    object
#  12  Code                        196 non-null    float64
#  13  On Hand End of Month        464 non-null    object
#  14  Formation Production        413 non-null    object
#  15  Volume.1                    236 non-null    object
#  16  Code.1                      236 non-null    float64
# dtypes: float64(5), object(12)
# memory usage: 65.2+ KB

# %% [markdown]
# ### Clean Oil Production Columns and Convert to Int

# %%
production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))

# %% [markdown]
# ### Rename Volume to rrc_oil_volume

# %%
production.rename(columns = {'Volume': 'rrc_oil_volume'}, inplace = True)
production.rename(columns = {'Volume.1': 'rrc_gas_volume'}, inplace = True)

# %%
production['rrc_oil_volume'].sum()
production['rrc_gas_volume'].sum()
# Out:
# 384725
# 1423678

# %% [markdown]
# ### Normalize Field and Reservoir Names with Text Cleaning

# %%
production["Normalized_Field_Name"] = production['Field Name'].dropna()\
                                                            .apply(lambda x: str(x).split('(')[0]\
                                                                                    .split(',')[0]\
                                                                                    .strip())

# %%
production["Normalized_Reservoir_Name"] = production['Field Name'].dropna()\
                                        .apply(lambda x: str(x).split('(')[-1]\
                                                               .strip().replace(')',''))

# %% [markdown]
# ### Get Date from Production File

# %%
def get_date_from_csv(filepath, col_number, row_number):
    str_date = pd.read_csv(filepath, usecols = [col_number]).iloc[row_number].values[0]
    return str_date.strip()

# %%
get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1)
# Out:
# 'Aug 2021'

# %% [markdown]
# ### Add Production Date to Production Data Frame

# %%
production.insert(0, 'Date', get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1))

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Aug 2021              NaN        Oil       8.0         32907.0
# 1    Aug 2021              NaN        Oil       8.0         20550.0
# 2    Aug 2021              NaN        Oil       8.0         45314.0
# 3    Aug 2021              NaN        Oil       8.0         48393.0
# 4    Aug 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 462  Aug 2021              NaN        Gas       8.0        147187.0
# 463  Aug 2021              NaN        Gas       8.0        190864.0
# 464  Aug 2021              NaN        Gas       8.0        190926.0
# 465  Aug 2021              NaN        Gas       8.0        205775.0
# 466  Aug 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 462  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 463  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 464  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 465  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 466   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        222         38
# 1                  7024.0                         39          0
# 2                     NaN                        183         89
# 3                  8026.0                      1,882      8,215
# 4                  8026.0                        485      1,253
# ..                    ...                        ...        ...
# 462                8988.0                          7         16
# 463                8988.0                          0          0
# 464                3501.0                          7         34
# 465                8092.0                          7         34
# 466                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  260                    0
# 1                 0   NaN                   39                    0
# 2                 0   NaN                  272                2,064
# 3              8165   0.0                1,932               28,894
# 4              1344   0.0                  394                6,773
# ..              ...   ...                  ...                  ...
# 462              16   1.0                    7                  800
# 463               0   NaN                    0                    0
# 464              27   1.0                   14                  649
# 465              27   1.0                   14                  891
# 466               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              2064     2.0                 ARMER                      6350
# 3             28894     2.0                 ARMER                      6350
# 4              6773     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 462             800     2.0               WADDELL                  GRAYBURG
# 463               0     NaN               WADDELL                  GRAYBURG
# 464             649     2.0               WADDELL                  GRAYBURG
# 465             891     2.0               WADDELL                  GRAYBURG
# 466               0     NaN                   -Y-                      TUBB
#
# [464 rows x 20 columns]

# %% [markdown]
# ### Add columns for net production to Trust

# %%
production['Net Oil Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50
production['Net Oil Sales Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50 * 0.75

# %%
production['Net Gas Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50
production['Net Gas Sales Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50 * 0.75

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Aug 2021              NaN        Oil       8.0         32907.0
# 1    Aug 2021              NaN        Oil       8.0         20550.0
# 2    Aug 2021              NaN        Oil       8.0         45314.0
# 3    Aug 2021              NaN        Oil       8.0         48393.0
# 4    Aug 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 462  Aug 2021              NaN        Gas       8.0        147187.0
# 463  Aug 2021              NaN        Gas       8.0        190864.0
# 464  Aug 2021              NaN        Gas       8.0        190926.0
# 465  Aug 2021              NaN        Gas       8.0        205775.0
# 466  Aug 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 462  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 463  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 464  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 465  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 466   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        222         38
# 1                  7024.0                         39          0
# 2                     NaN                        183         89
# 3                  8026.0                      1,882      8,215
# 4                  8026.0                        485      1,253
# ..                    ...                        ...        ...
# 462                8988.0                          7         16
# 463                8988.0                          0          0
# 464                3501.0                          7         34
# 465                8092.0                          7         34
# 466                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  260                    0
# 1                 0   NaN                   39                    0
# 2                 0   NaN                  272                2,064
# 3              8165   0.0                1,932               28,894
# 4              1344   0.0                  394                6,773
# ..              ...   ...                  ...                  ...
# 462              16   1.0                    7                  800
# 463               0   NaN                    0                    0
# 464              27   1.0                   14                  649
# 465              27   1.0                   14                  891
# 466               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name  \
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              2064     2.0                 ARMER                      6350
# 3             28894     2.0                 ARMER                      6350
# 4              6773     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 462             800     2.0               WADDELL                  GRAYBURG
# 463               0     NaN               WADDELL                  GRAYBURG
# 464             649     2.0               WADDELL                  GRAYBURG
# 465             891     2.0               WADDELL                  GRAYBURG
# 466               0     NaN                   -Y-                      TUBB
#
#      Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                              0.0                                0.000
# 3                           4082.5                             3061.875
# 4                            672.0                              504.000
# ..                             ...                                  ...
# 462                            8.0                                6.000
# 463                            0.0                                0.000
# 464                           13.5                               10.125
# 465                           13.5                               10.125
# 466                            0.0                                0.000
#
#      Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                           1032.0                              774.000
# 3                          14447.0                            10835.250
# 4                           3386.5                             2539.875
# ..                             ...                                  ...
# 462                          400.0                              300.000
# 463                            0.0                                0.000
# 464                          324.5                              243.375
# 465                          445.5                              334.125
# 466                            0.0                                0.000
#
# [464 rows x 24 columns]

# %% [markdown]
# ### Write to File

# %%
production.to_csv(f'{processed_data_folder}/rrc_prod/{file_name}', index = False)

# %% [markdown]
# ## Aggregated EDA

# %%
production.groupby(['Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'})\
                                            .sort_values(by = 'rrc_oil_volume', ascending= False)\
                                            .head(15)
# Out:
#                        rrc_oil_volume
# Normalized_Field_Name
# SAND HILLS                     220704
# MONAHANS                        76707
# ARMER                           35633
# DUNE                            18193
# UNIVERSITY WADDELL               9698
# MARSTON RANCH                    8876
# WADDELL                          5737
# RUNNING W                        5005
# CORDONA LAKE                     2800
# LEA                              1023
# BLOCK 31                          177
# DELL                              172
# SHAFTER LAKE                        0
# RM                                  0
# MCKEE                               0

# %%
production.groupby(['Normalized_Reservoir_Name', 'Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'}).sort_values(by = 'rrc_oil_volume', ascending= False).sort_index()
# Out:
#                                                  rrc_oil_volume
# Normalized_Reservoir_Name Normalized_Field_Name
# 6350                      ARMER                           35633
# 7900                      EDWARDS -04-                        0
# CLEAR FORK                LEA                               299
#                           MONAHANS                            0
#                           SAND HILLS                      38060
# CLEAR FORK 4070           SAND HILLS                        301
# CLEAR FORK, LOWER         MCKEE                               0
# CLEAR FORK, MID.          MCKEE                               0
# CLEARFORK                 MARSTON RANCH                    8876
#                           MONAHANS                        69081
#                           RM                                  0
# COLBY                     KEYSTONE                            0
# CONSOLIDATED              KEYSTONE                            0
# CORDONA LAKE              CORDONA LAKE                      204
# COWDEN, NORTH             COWDEN                              0
# DEV.                      CORDONA LAKE                     2173
# DEVONIAN                  CORDONA LAKE                      167
#                           UNIVERSITY WADDELL               8823
#                           WADDELL                           119
# DUNE                      DUNE                            18192
# ELLENBURGER               KERMIT                              0
#                           SAND HILLS                        622
#                           UNIVERSITY WADDELL                  0
# GLORIETA                  MONAHANS                          818
# GRAYBURG                  GOLDSMITH                           0
#                           WADDELL                           348
# HOLT                      RUNNING W                          48
#                           SAND HILLS                          0
# JUDKINS                   SAND HILLS                      15960
# KERMIT                    KERMIT                              0
# MCKEE                     BLOCK 27                            0
#                           KERMIT                              0
#                           RUNNING W                           0
# MCKNIGHT                  SAND HILLS                      41424
# MONAHANS, NORTH           MONAHANS                         6808
# ORDOVICIAN                SAND HILLS                          0
# PENN UPPER                BLOCK 31                          177
# PENN.                     G. P. M.                            0
#                           UNIVERSITY WADDELL                 27
# QUEEN                     GOLDSMITH                           0
# SAN ANDRES                C-BAR                               0
#                           DELL                              172
#                           KEYSTONE                            0
#                           LEA                                59
#                           SHAFTER LAKE                        0
# SAN ANDRES CONS.          CRAWAR                              0
# SAN ANDRES, CON.          GOLDSMITH                           0
# SAN ANGELO                LEA                               665
#                           SAND HILLS                       1781
# SAN ANGELO, UPPER         SAND HILLS                      29173
# TUBB                      -Y-                                 0
#                           ARMER                               0
#                           BLOCK B-21                          0
#                           RUNNING W                         917
#                           SAND HILLS                      50212
# TUBB 4500                 CORDONA LAKE                      256
# WADDELL                   RUNNING W                        3383
#                           WADDELL                          5270
# WADDELL SD.               UNIVERSITY WADDELL                848
# WICHITA-ALBANY            RUNNING W                         657
#                           SAND HILLS                      23506
# WICHITA-ALBANY, GAS       SAND HILLS                       1215
# WOJCIK-MCELROY            SAND HILLS                        241
# WOLFCAMP                  DUNE                                1
#                           MCKEE                               0
#                           SAND HILLS                      18209
# YATES                     KERMIT                              0
