# %%
import pandas as pd
import datetime as dt

pd.options.display.max_columns=1000
pd.options.display.max_rows = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %run configs.ipynb

# %%
# parameter cell
file_name = 'oct_21.csv'

# %%
# Parameters
file_name = "september_21.csv"

# %% [markdown]
# # RRC Prod

# %% [markdown]
# ## Ingest

# %%
production = pd.read_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', header = 5)

# %%
production.head()
# Out:
#   Multiple Reports Lease Type  District  RRC Identifier    Field Name  \
# 0              NaN        Oil       8.0         32907.0  ARMER (TUBB)
# 1              NaN        Oil       8.0         20550.0  ARMER (6350)
# 2              NaN        Oil       8.0         45314.0  ARMER (6350)
# 3              NaN        Oil       8.0         48393.0  ARMER (6350)
# 4              NaN        Oil       8.0         49425.0  ARMER (6350)
#
#                     Lease Name Gas Well ID Lease Total  Commingle Permit No.  \
# 0   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN                7024.0
# 1  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN                7024.0
# 2               RAYDEN MCCAMEY         NaN         NaN                   NaN
# 3                   LANDLUBBER         NaN         NaN                8026.0
# 4                 6 POUNDER NE         NaN         NaN                8026.0
#
#   On Hand Beginning of Month Production Volume  Code On Hand End of Month  \
# 0                        260         23    143   1.0                  140
# 1                         39          0     21   1.0                   18
# 2                        272        161    172   1.0                  261
# 3                      1,932      7,137  7,348   0.0                1,721
# 4                        394      1,569  1,456   0.0                  507
#
#   Formation Production Volume.1  Code.1
# 0                    0      NaN     NaN
# 1                    0      NaN     NaN
# 2                1,941    1,941     2.0
# 3               21,352   21,352     2.0
# 4                3,346    3,346     2.0

# %% [markdown]
# ## Transform RRC

# %% [markdown]
# ### Filter to District

# %%
#converting data field to string to handle varying schema interpreations 
#(certain months field will be interpreted as float and string depending sample rows pandas uses

production = production.loc[production['District'].astype(str).isin(['8.0', '08', '8'])]

# %%
production
# Out:
#     Multiple Reports Lease Type  District  RRC Identifier          Field Name  \
# 0                NaN        Oil       8.0         32907.0        ARMER (TUBB)
# 1                NaN        Oil       8.0         20550.0        ARMER (6350)
# 2                NaN        Oil       8.0         45314.0        ARMER (6350)
# 3                NaN        Oil       8.0         48393.0        ARMER (6350)
# 4                NaN        Oil       8.0         49425.0        ARMER (6350)
# ..               ...        ...       ...             ...                 ...
# 435              NaN        Gas       8.0        147187.0  WADDELL (GRAYBURG)
# 436              NaN        Gas       8.0        190864.0  WADDELL (GRAYBURG)
# 437              NaN        Gas       8.0        190926.0  WADDELL (GRAYBURG)
# 438              NaN        Gas       8.0        205775.0  WADDELL (GRAYBURG)
# 439              NaN        Oil       8.0         20361.0   -Y-, SOUTH (TUBB)
#
#                       Lease Name Gas Well ID Lease Total  \
# 0     MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1    MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2                 RAYDEN MCCAMEY         NaN         NaN
# 3                     LANDLUBBER         NaN         NaN
# 4                   6 POUNDER NE         NaN         NaN
# ..                           ...         ...         ...
# 435                WADDELL, W.N.       859           NaN
# 436                WADDELL, W.N.       890           NaN
# 437                WADDELL, W.N.       293           NaN
# 438               WADDELL, W. N.      1200           NaN
# 439  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production Volume  Code  \
# 0                  7024.0                        260         23    143   1.0
# 1                  7024.0                         39          0     21   1.0
# 2                     NaN                        272        161    172   1.0
# 3                  8026.0                      1,932      7,137  7,348   0.0
# 4                  8026.0                        394      1,569  1,456   0.0
# ..                    ...                        ...        ...    ...   ...
# 435                8988.0                          7         26     25   1.0
# 436                8988.0                          0          0    NaN   NaN
# 437                3501.0                         14         26     32   1.0
# 438                8092.0                         14         27     33   1.0
# 439                3803.0                          0          0    NaN   NaN
#
#     On Hand End of Month Formation Production Volume.1  Code.1
# 0                    140                    0      NaN     NaN
# 1                     18                    0      NaN     NaN
# 2                    261                1,941    1,941     2.0
# 3                  1,721               21,352   21,352     2.0
# 4                    507                3,346    3,346     2.0
# ..                   ...                  ...      ...     ...
# 435                    8                  509      509     2.0
# 436                    0                    0      NaN     NaN
# 437                    8                  459      459     2.0
# 438                    8                  486      486     2.0
# 439                    0                    0      NaN     NaN
#
# [437 rows x 17 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 437 entries, 0 to 439
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Multiple Reports            57 non-null     object
#  1   Lease Type                  384 non-null    object
#  2   District                    437 non-null    float64
#  3   RRC Identifier              437 non-null    float64
#  4   Field Name                  437 non-null    object
#  5   Lease Name                  437 non-null    object
#  6   Gas Well ID                 220 non-null    object
#  7   Lease Total                 13 non-null     object
#  8   Commingle Permit No.        270 non-null    float64
#  9   On Hand Beginning of Month  398 non-null    object
#  10  Production                  437 non-null    object
#  11  Volume                      191 non-null    object
#  12  Code                        191 non-null    float64
#  13  On Hand End of Month        437 non-null    object
#  14  Formation Production        386 non-null    object
#  15  Volume.1                    228 non-null    object
#  16  Code.1                      228 non-null    float64
# dtypes: float64(5), object(12)
# memory usage: 61.5+ KB

# %% [markdown]
# ### Clean Oil Production Columns and Convert to Int

# %%
production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))

# %% [markdown]
# ### Rename Volume to rrc_oil_volume

# %%
production.rename(columns = {'Volume': 'rrc_oil_volume'}, inplace = True)
production.rename(columns = {'Volume.1': 'rrc_gas_volume'}, inplace = True)

# %%
production['rrc_oil_volume'].sum()
production['rrc_gas_volume'].sum()
# Out:
# 375220
# 1352958

# %% [markdown]
# ### Normalize Field and Reservoir Names with Text Cleaning

# %%
production["Normalized_Field_Name"] = production['Field Name'].dropna()\
                                                            .apply(lambda x: str(x).split('(')[0]\
                                                                                    .split(',')[0]\
                                                                                    .strip())

# %%
production["Normalized_Reservoir_Name"] = production['Field Name'].dropna()\
                                        .apply(lambda x: str(x).split('(')[-1]\
                                                               .strip().replace(')',''))

# %% [markdown]
# ### Get Date from Production File

# %%
def get_date_from_csv(filepath, col_number, row_number):
    str_date = pd.read_csv(filepath, usecols = [col_number]).iloc[row_number].values[0]
    return str_date.strip()

# %%
get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1)
# Out:
# 'Sept 2021'

# %% [markdown]
# ### Add Production Date to Production Data Frame

# %%
production.insert(0, 'Date', get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1))

# %%
production
# Out:
#           Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Sept 2021              NaN        Oil       8.0         32907.0
# 1    Sept 2021              NaN        Oil       8.0         20550.0
# 2    Sept 2021              NaN        Oil       8.0         45314.0
# 3    Sept 2021              NaN        Oil       8.0         48393.0
# 4    Sept 2021              NaN        Oil       8.0         49425.0
# ..         ...              ...        ...       ...             ...
# 435  Sept 2021              NaN        Gas       8.0        147187.0
# 436  Sept 2021              NaN        Gas       8.0        190864.0
# 437  Sept 2021              NaN        Gas       8.0        190926.0
# 438  Sept 2021              NaN        Gas       8.0        205775.0
# 439  Sept 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 435  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 436  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 437  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 438  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 439   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        260         23
# 1                  7024.0                         39          0
# 2                     NaN                        272        161
# 3                  8026.0                      1,932      7,137
# 4                  8026.0                        394      1,569
# ..                    ...                        ...        ...
# 435                8988.0                          7         26
# 436                8988.0                          0          0
# 437                3501.0                         14         26
# 438                8092.0                         14         27
# 439                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0               143   1.0                  140                    0
# 1                21   1.0                   18                    0
# 2               172   1.0                  261                1,941
# 3              7348   0.0                1,721               21,352
# 4              1456   0.0                  507                3,346
# ..              ...   ...                  ...                  ...
# 435              25   1.0                    8                  509
# 436               0   NaN                    0                    0
# 437              32   1.0                    8                  459
# 438              33   1.0                    8                  486
# 439               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              1941     2.0                 ARMER                      6350
# 3             21352     2.0                 ARMER                      6350
# 4              3346     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 435             509     2.0               WADDELL                  GRAYBURG
# 436               0     NaN               WADDELL                  GRAYBURG
# 437             459     2.0               WADDELL                  GRAYBURG
# 438             486     2.0               WADDELL                  GRAYBURG
# 439               0     NaN                   -Y-                      TUBB
#
# [437 rows x 20 columns]

# %% [markdown]
# ### Add columns for net production to Trust

# %%
production['Net Oil Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50
production['Net Oil Sales Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50 * 0.75

# %%
production['Net Gas Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50
production['Net Gas Sales Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50 * 0.75

# %%
production
# Out:
#           Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Sept 2021              NaN        Oil       8.0         32907.0
# 1    Sept 2021              NaN        Oil       8.0         20550.0
# 2    Sept 2021              NaN        Oil       8.0         45314.0
# 3    Sept 2021              NaN        Oil       8.0         48393.0
# 4    Sept 2021              NaN        Oil       8.0         49425.0
# ..         ...              ...        ...       ...             ...
# 435  Sept 2021              NaN        Gas       8.0        147187.0
# 436  Sept 2021              NaN        Gas       8.0        190864.0
# 437  Sept 2021              NaN        Gas       8.0        190926.0
# 438  Sept 2021              NaN        Gas       8.0        205775.0
# 439  Sept 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 435  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 436  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 437  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 438  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 439   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        260         23
# 1                  7024.0                         39          0
# 2                     NaN                        272        161
# 3                  8026.0                      1,932      7,137
# 4                  8026.0                        394      1,569
# ..                    ...                        ...        ...
# 435                8988.0                          7         26
# 436                8988.0                          0          0
# 437                3501.0                         14         26
# 438                8092.0                         14         27
# 439                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0               143   1.0                  140                    0
# 1                21   1.0                   18                    0
# 2               172   1.0                  261                1,941
# 3              7348   0.0                1,721               21,352
# 4              1456   0.0                  507                3,346
# ..              ...   ...                  ...                  ...
# 435              25   1.0                    8                  509
# 436               0   NaN                    0                    0
# 437              32   1.0                    8                  459
# 438              33   1.0                    8                  486
# 439               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name  \
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              1941     2.0                 ARMER                      6350
# 3             21352     2.0                 ARMER                      6350
# 4              3346     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 435             509     2.0               WADDELL                  GRAYBURG
# 436               0     NaN               WADDELL                  GRAYBURG
# 437             459     2.0               WADDELL                  GRAYBURG
# 438             486     2.0               WADDELL                  GRAYBURG
# 439               0     NaN                   -Y-                      TUBB
#
#      Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 0                             71.5                               53.625
# 1                             10.5                                7.875
# 2                             86.0                               64.500
# 3                           3674.0                             2755.500
# 4                            728.0                              546.000
# ..                             ...                                  ...
# 435                           12.5                                9.375
# 436                            0.0                                0.000
# 437                           16.0                               12.000
# 438                           16.5                               12.375
# 439                            0.0                                0.000
#
#      Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                            970.5                              727.875
# 3                          10676.0                             8007.000
# 4                           1673.0                             1254.750
# ..                             ...                                  ...
# 435                          254.5                              190.875
# 436                            0.0                                0.000
# 437                          229.5                              172.125
# 438                          243.0                              182.250
# 439                            0.0                                0.000
#
# [437 rows x 24 columns]

# %% [markdown]
# ### Write to File

# %%
production.to_csv(f'{processed_data_folder}/rrc_prod/{file_name}', index = False)

# %% [markdown]
# ## Aggregated EDA

# %%
production.groupby(['Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'})\
                                            .sort_values(by = 'rrc_oil_volume', ascending= False)\
                                            .head(15)
# Out:
#                        rrc_oil_volume
# Normalized_Field_Name
# SAND HILLS                     225485
# MONAHANS                        65789
# ARMER                           31851
# DUNE                            17598
# UNIVERSITY WADDELL              10854
# MARSTON RANCH                    8539
# WADDELL                          6113
# RUNNING W                        4855
# CORDONA LAKE                     2677
# LEA                              1108
# G. P. M.                          178
# BLOCK 31                          173
# EDWARDS -04-                        0
# DELL                                0
# KERMIT                              0

# %%
production.groupby(['Normalized_Reservoir_Name', 'Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'}).sort_values(by = 'rrc_oil_volume', ascending= False).sort_index()
# Out:
#                                                  rrc_oil_volume
# Normalized_Reservoir_Name Normalized_Field_Name
# 6350                      ARMER                           31708
# 7900                      EDWARDS -04-                        0
# CLEAR FORK                LEA                               265
#                           MONAHANS                            0
#                           SAND HILLS                      35946
# CLEAR FORK 4070           SAND HILLS                         12
# CLEAR FORK, LOWER         MCKEE                               0
# CLEAR FORK, MID.          MCKEE                               0
# CLEARFORK                 MARSTON RANCH                    8539
#                           MONAHANS                        59518
#                           RM                                  0
# COLBY                     KEYSTONE                            0
# CONSOLIDATED              KEYSTONE                            0
# CORDONA LAKE              CORDONA LAKE                      273
# COWDEN, NORTH             COWDEN                              0
# DEV.                      CORDONA LAKE                     1923
# DEVONIAN                  CORDONA LAKE                      177
#                           UNIVERSITY WADDELL               9799
#                           WADDELL                            97
# DUNE                      DUNE                            17579
# ELLENBURGER               KERMIT                              0
#                           SAND HILLS                        532
#                           UNIVERSITY WADDELL                  0
# GLORIETA                  MONAHANS                         1165
# GRAYBURG                  WADDELL                           374
# HOLT                      RUNNING W                          65
#                           SAND HILLS                          0
# JUDKINS                   SAND HILLS                      20568
# KERMIT                    KERMIT                              0
# MCKEE                     BLOCK 27                            0
#                           KERMIT                              0
#                           RUNNING W                           0
# MCKNIGHT                  SAND HILLS                      45108
# MONAHANS, NORTH           MONAHANS                         5106
# ORDOVICIAN                SAND HILLS                          0
# PENN UPPER                BLOCK 31                          173
# PENN.                     G. P. M.                          178
#                           UNIVERSITY WADDELL                 32
# SAN ANDRES                C-BAR                               0
#                           DELL                                0
#                           KEYSTONE                            0
#                           LEA                                66
# SAN ANDRES CONS.          CRAWAR                              0
# SAN ANGELO                LEA                               777
#                           SAND HILLS                       1082
# SAN ANGELO, UPPER         SAND HILLS                      28825
# TUBB                      -Y-                                 0
#                           ARMER                             143
#                           BLOCK B-21                          0
#                           RUNNING W                        1142
#                           SAND HILLS                      44683
# TUBB 4500                 CORDONA LAKE                      304
# WADDELL                   RUNNING W                        2971
#                           WADDELL                          5642
# WADDELL SD.               UNIVERSITY WADDELL               1023
# WICHITA-ALBANY            RUNNING W                         677
#                           SAND HILLS                      27542
# WICHITA-ALBANY, GAS       SAND HILLS                        986
# WOJCIK-MCELROY            SAND HILLS                        263
# WOLFCAMP                  DUNE                               19
#                           MCKEE                               0
#                           SAND HILLS                      19938
# YATES                     KERMIT                              0
