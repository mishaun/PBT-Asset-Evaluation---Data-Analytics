# %%
import pandas as pd
import datetime as dt

pd.options.display.max_columns=1000
pd.options.display.max_rows = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %run configs.ipynb

# %%
# parameter cell
file_name = 'oct_21.csv'

# %%
# Parameters
file_name = "nov_21.csv"

# %% [markdown]
# # RRC Prod

# %% [markdown]
# ## Ingest

# %%
production = pd.read_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', header = 5)

# %%
production.head()
# Out:
#   Multiple Reports Lease Type  District  RRC Identifier    Field Name  \
# 0              NaN        Oil       8.0         32907.0  ARMER (TUBB)
# 1              NaN        Oil       8.0         20550.0  ARMER (6350)
# 2              NaN        Oil       8.0         45314.0  ARMER (6350)
# 3              NaN        Oil       8.0         48393.0  ARMER (6350)
# 4              NaN        Oil       8.0         49425.0  ARMER (6350)
#
#                     Lease Name Gas Well ID Lease Total  Commingle Permit No.  \
# 0   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN                7024.0
# 1  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN                7024.0
# 2               RAYDEN MCCAMEY         NaN         NaN                   NaN
# 3                   LANDLUBBER         NaN         NaN                8026.0
# 4                 6 POUNDER NE         NaN         NaN                8026.0
#
#   On Hand Beginning of Month Production Volume  Code On Hand End of Month  \
# 0                        166         38    NaN   NaN                  204
# 1                         18          0    NaN   NaN                   18
# 2                        165         85    NaN   NaN                  250
# 3                      1,452      6,098  6,499   0.0                1,051
# 4                        193        866    869   0.0                  190
#
#   Formation Production Volume.1  Code.1
# 0                    0      NaN     NaN
# 1                    0      NaN     NaN
# 2                  447      447     2.0
# 3               18,593   18,593     2.0
# 4                4,149    4,149     2.0

# %% [markdown]
# ## Transform RRC

# %% [markdown]
# ### Filter to District

# %%
#converting data field to string to handle varying schema interpreations 
#(certain months field will be interpreted as float and string depending sample rows pandas uses

production = production.loc[production['District'].astype(str).isin(['8.0', '08', '8'])]

# %%
production
# Out:
#     Multiple Reports Lease Type  District  RRC Identifier          Field Name  \
# 0                NaN        Oil       8.0         32907.0        ARMER (TUBB)
# 1                NaN        Oil       8.0         20550.0        ARMER (6350)
# 2                NaN        Oil       8.0         45314.0        ARMER (6350)
# 3                NaN        Oil       8.0         48393.0        ARMER (6350)
# 4                NaN        Oil       8.0         49425.0        ARMER (6350)
# ..               ...        ...       ...             ...                 ...
# 459                Y        Gas       8.0        147187.0  WADDELL (GRAYBURG)
# 460              NaN        Gas       8.0        190864.0  WADDELL (GRAYBURG)
# 461                Y        Gas       8.0        190926.0  WADDELL (GRAYBURG)
# 462                Y        Gas       8.0        205775.0  WADDELL (GRAYBURG)
# 463              NaN        Oil       8.0         20361.0   -Y-, SOUTH (TUBB)
#
#                       Lease Name Gas Well ID Lease Total  \
# 0     MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1    MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2                 RAYDEN MCCAMEY         NaN         NaN
# 3                     LANDLUBBER         NaN         NaN
# 4                   6 POUNDER NE         NaN         NaN
# ..                           ...         ...         ...
# 459                WADDELL, W.N.       859           NaN
# 460                WADDELL, W.N.       890           NaN
# 461                WADDELL, W.N.       293           NaN
# 462               WADDELL, W. N.      1200           NaN
# 463  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production Volume  Code  \
# 0                  7024.0                        166         38    NaN   NaN
# 1                  7024.0                         18          0    NaN   NaN
# 2                     NaN                        165         85    NaN   NaN
# 3                  8026.0                      1,452      6,098  6,499   0.0
# 4                  8026.0                        193        866    869   0.0
# ..                    ...                        ...        ...    ...   ...
# 459                8988.0                          2         28     28   1.0
# 460                8988.0                          0          0    NaN   NaN
# 461                3501.0                          2         28     28   1.0
# 462                8092.0                          2         28     28   1.0
# 463                3803.0                          0          0    NaN   NaN
#
#     On Hand End of Month Formation Production Volume.1  Code.1
# 0                    204                    0      NaN     NaN
# 1                     18                    0      NaN     NaN
# 2                    250                  447      447     2.0
# 3                  1,051               18,593   18,593     2.0
# 4                    190                4,149    4,149     2.0
# ..                   ...                  ...      ...     ...
# 459                    2                  554      554     2.0
# 460                    0                    0      NaN     NaN
# 461                    2                  362      362     2.0
# 462                    2                  532      532     2.0
# 463                    0                    0      NaN     NaN
#
# [460 rows x 17 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460 entries, 0 to 463
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Multiple Reports            233 non-null    object
#  1   Lease Type                  406 non-null    object
#  2   District                    460 non-null    float64
#  3   RRC Identifier              460 non-null    float64
#  4   Field Name                  460 non-null    object
#  5   Lease Name                  460 non-null    object
#  6   Gas Well ID                 232 non-null    object
#  7   Lease Total                 13 non-null     object
#  8   Commingle Permit No.        270 non-null    float64
#  9   On Hand Beginning of Month  407 non-null    object
#  10  Production                  460 non-null    object
#  11  Volume                      183 non-null    object
#  12  Code                        183 non-null    float64
#  13  On Hand End of Month        460 non-null    object
#  14  Formation Production        412 non-null    object
#  15  Volume.1                    222 non-null    object
#  16  Code.1                      222 non-null    float64
# dtypes: float64(5), object(12)
# memory usage: 64.7+ KB

# %% [markdown]
# ### Clean Oil Production Columns and Convert to Int

# %%
production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))

# %% [markdown]
# ### Rename Volume to rrc_oil_volume

# %%
production.rename(columns = {'Volume': 'rrc_oil_volume'}, inplace = True)
production.rename(columns = {'Volume.1': 'rrc_gas_volume'}, inplace = True)

# %%
production['rrc_oil_volume'].sum()
production['rrc_gas_volume'].sum()
# Out:
# 362868
# 1415945

# %% [markdown]
# ### Normalize Field and Reservoir Names with Text Cleaning

# %%
production["Normalized_Field_Name"] = production['Field Name'].dropna()\
                                                            .apply(lambda x: str(x).split('(')[0]\
                                                                                    .split(',')[0]\
                                                                                    .strip())

# %%
production["Normalized_Reservoir_Name"] = production['Field Name'].dropna()\
                                        .apply(lambda x: str(x).split('(')[-1]\
                                                               .strip().replace(')',''))

# %% [markdown]
# ### Get Date from Production File

# %%
def get_date_from_csv(filepath, col_number, row_number):
    str_date = pd.read_csv(filepath, usecols = [col_number]).iloc[row_number].values[0]
    return str_date.strip()

# %%
get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1)
# Out:
# 'Nov 2021'

# %% [markdown]
# ### Add Production Date to Production Data Frame

# %%
production.insert(0, 'Date', get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1))

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Nov 2021              NaN        Oil       8.0         32907.0
# 1    Nov 2021              NaN        Oil       8.0         20550.0
# 2    Nov 2021              NaN        Oil       8.0         45314.0
# 3    Nov 2021              NaN        Oil       8.0         48393.0
# 4    Nov 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 459  Nov 2021                Y        Gas       8.0        147187.0
# 460  Nov 2021              NaN        Gas       8.0        190864.0
# 461  Nov 2021                Y        Gas       8.0        190926.0
# 462  Nov 2021                Y        Gas       8.0        205775.0
# 463  Nov 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 459  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 460  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 461  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 462  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 463   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        166         38
# 1                  7024.0                         18          0
# 2                     NaN                        165         85
# 3                  8026.0                      1,452      6,098
# 4                  8026.0                        193        866
# ..                    ...                        ...        ...
# 459                8988.0                          2         28
# 460                8988.0                          0          0
# 461                3501.0                          2         28
# 462                8092.0                          2         28
# 463                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  204                    0
# 1                 0   NaN                   18                    0
# 2                 0   NaN                  250                  447
# 3              6499   0.0                1,051               18,593
# 4               869   0.0                  190                4,149
# ..              ...   ...                  ...                  ...
# 459              28   1.0                    2                  554
# 460               0   NaN                    0                    0
# 461              28   1.0                    2                  362
# 462              28   1.0                    2                  532
# 463               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2               447     2.0                 ARMER                      6350
# 3             18593     2.0                 ARMER                      6350
# 4              4149     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 459             554     2.0               WADDELL                  GRAYBURG
# 460               0     NaN               WADDELL                  GRAYBURG
# 461             362     2.0               WADDELL                  GRAYBURG
# 462             532     2.0               WADDELL                  GRAYBURG
# 463               0     NaN                   -Y-                      TUBB
#
# [460 rows x 20 columns]

# %% [markdown]
# ### Add columns for net production to Trust

# %%
production['Net Oil Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50
production['Net Oil Sales Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50 * 0.75

# %%
production['Net Gas Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50
production['Net Gas Sales Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50 * 0.75

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Nov 2021              NaN        Oil       8.0         32907.0
# 1    Nov 2021              NaN        Oil       8.0         20550.0
# 2    Nov 2021              NaN        Oil       8.0         45314.0
# 3    Nov 2021              NaN        Oil       8.0         48393.0
# 4    Nov 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 459  Nov 2021                Y        Gas       8.0        147187.0
# 460  Nov 2021              NaN        Gas       8.0        190864.0
# 461  Nov 2021                Y        Gas       8.0        190926.0
# 462  Nov 2021                Y        Gas       8.0        205775.0
# 463  Nov 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 459  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 460  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 461  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 462  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 463   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        166         38
# 1                  7024.0                         18          0
# 2                     NaN                        165         85
# 3                  8026.0                      1,452      6,098
# 4                  8026.0                        193        866
# ..                    ...                        ...        ...
# 459                8988.0                          2         28
# 460                8988.0                          0          0
# 461                3501.0                          2         28
# 462                8092.0                          2         28
# 463                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  204                    0
# 1                 0   NaN                   18                    0
# 2                 0   NaN                  250                  447
# 3              6499   0.0                1,051               18,593
# 4               869   0.0                  190                4,149
# ..              ...   ...                  ...                  ...
# 459              28   1.0                    2                  554
# 460               0   NaN                    0                    0
# 461              28   1.0                    2                  362
# 462              28   1.0                    2                  532
# 463               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name  \
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2               447     2.0                 ARMER                      6350
# 3             18593     2.0                 ARMER                      6350
# 4              4149     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 459             554     2.0               WADDELL                  GRAYBURG
# 460               0     NaN               WADDELL                  GRAYBURG
# 461             362     2.0               WADDELL                  GRAYBURG
# 462             532     2.0               WADDELL                  GRAYBURG
# 463               0     NaN                   -Y-                      TUBB
#
#      Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                              0.0                                0.000
# 3                           3249.5                             2437.125
# 4                            434.5                              325.875
# ..                             ...                                  ...
# 459                           14.0                               10.500
# 460                            0.0                                0.000
# 461                           14.0                               10.500
# 462                           14.0                               10.500
# 463                            0.0                                0.000
#
#      Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                            223.5                              167.625
# 3                           9296.5                             6972.375
# 4                           2074.5                             1555.875
# ..                             ...                                  ...
# 459                          277.0                              207.750
# 460                            0.0                                0.000
# 461                          181.0                              135.750
# 462                          266.0                              199.500
# 463                            0.0                                0.000
#
# [460 rows x 24 columns]

# %% [markdown]
# ### Write to File

# %%
production.to_csv(f'{processed_data_folder}/rrc_prod/{file_name}', index = False)

# %% [markdown]
# ## Aggregated EDA

# %%
production.groupby(['Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'})\
                                            .sort_values(by = 'rrc_oil_volume', ascending= False)\
                                            .head(15)
# Out:
#                        rrc_oil_volume
# Normalized_Field_Name
# SAND HILLS                     230210
# MONAHANS                        62167
# ARMER                           29074
# DUNE                            16874
# MARSTON RANCH                    8422
# RUNNING W                        5604
# WADDELL                          4307
# UNIVERSITY WADDELL               2511
# CORDONA LAKE                     1907
# LEA                              1454
# BLOCK 31                          186
# G. P. M.                          152
# SHAFTER LAKE                        0
# RM                                  0
# MCKEE                               0

# %%
production.groupby(['Normalized_Reservoir_Name', 'Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'}).sort_values(by = 'rrc_oil_volume', ascending= False).sort_index()
# Out:
#                                                  rrc_oil_volume
# Normalized_Reservoir_Name Normalized_Field_Name
# 6350                      ARMER                           29074
# 7900                      EDWARDS -04-                        0
# CLEAR FORK                LEA                               342
#                           MONAHANS                            0
#                           SAND HILLS                      32761
# CLEAR FORK 4070           SAND HILLS                        670
# CLEAR FORK, LOWER         MCKEE                               0
# CLEAR FORK, MID.          MCKEE                               0
# CLEARFORK                 MARSTON RANCH                    8422
#                           MONAHANS                        56623
#                           RM                                  0
# COLBY                     KEYSTONE                            0
# CONSOLIDATED              KEYSTONE                            0
# CORDONA LAKE              CORDONA LAKE                       76
# COWDEN, NORTH             COWDEN                              0
# DEV.                      CORDONA LAKE                     1700
# DEVONIAN                  CORDONA LAKE                      127
#                           UNIVERSITY WADDELL               1493
#                           WADDELL                            71
# DUNE                      DUNE                            16873
# ELLENBURGER               KERMIT                              0
#                           SAND HILLS                       5260
#                           UNIVERSITY WADDELL                  0
# GLORIETA                  MONAHANS                         1004
# GRAYBURG                  GOLDSMITH                           0
#                           WADDELL                           281
# HOLT                      RUNNING W                          40
#                           SAND HILLS                          0
# JUDKINS                   SAND HILLS                      17241
# KERMIT                    KERMIT                              0
# MCKEE                     BLOCK 27                            0
#                           KERMIT                              0
#                           RUNNING W                           0
# MCKNIGHT                  SAND HILLS                      47087
# MONAHANS, NORTH           MONAHANS                         4540
# ORDOVICIAN                SAND HILLS                          0
# PENN UPPER                BLOCK 31                          186
# PENN.                     G. P. M.                          152
#                           UNIVERSITY WADDELL                 80
# QUEEN                     GOLDSMITH                           0
# SAN ANDRES                C-BAR                               0
#                           DELL                                0
#                           KEYSTONE                            0
#                           LEA                                79
#                           SHAFTER LAKE                        0
# SAN ANDRES CONS.          CRAWAR                              0
# SAN ANDRES, CON.          GOLDSMITH                           0
# SAN ANGELO                LEA                              1033
#                           SAND HILLS                        444
# SAN ANGELO, UPPER         SAND HILLS                      35737
# TUBB                      -Y-                                 0
#                           ARMER                               0
#                           BLOCK B-21                          0
#                           RUNNING W                        1621
#                           SAND HILLS                      48548
# TUBB 4500                 CORDONA LAKE                        4
# WADDELL                   RUNNING W                        3440
#                           WADDELL                          3955
# WADDELL SD.               UNIVERSITY WADDELL                938
# WICHITA-ALBANY            RUNNING W                         503
#                           SAND HILLS                      20994
# WICHITA-ALBANY, GAS       SAND HILLS                        562
# WOJCIK-MCELROY            SAND HILLS                        376
# WOLFCAMP                  DUNE                                1
#                           MCKEE                               0
#                           SAND HILLS                      20530
# YATES                     KERMIT                              0
