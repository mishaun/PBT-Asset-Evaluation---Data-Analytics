# %%
import pandas as pd
import datetime as dt

pd.options.display.max_columns=1000
pd.options.display.max_rows = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %run ../../configs.ipynb

# %%
# parameter cell
file_name = 'oct_21.csv'

# %%
# Parameters
file_name = "april_21.csv"

# %% [markdown]
# # RRC Prod

# %% [markdown]
# ## Ingest

# %%
production = pd.read_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', header = 5)

# %%
production.head()
# Out:
#   Multiple Reports Lease Type District  RRC Identifier  \
# 0              NaN        Gas       05        164066.0
# 1              NaN        Gas       7B        211352.0
# 2              NaN        Gas       7B        212409.0
# 3              NaN        Gas       7B        228695.0
# 4              NaN        Gas       7B        228926.0
#
#                Field Name                   Lease Name Gas Well ID  \
# 0        DUBOIS (BARNETT)                        MILES         1
# 1  GRANBURY, N.E. (ATOKA)                      LANGDON         2
# 2  GRANBURY, N.E. (ATOKA)  JOHN J. MILES, JR. GAS UNIT         4
# 3  GRANBURY, N.E. (ATOKA)                    LUCY UNIT         2
# 4  GRANBURY, N.E. (ATOKA)              MARSHALL, SAM A         2
#
#   Lease Total  Commingle Permit No. On Hand Beginning of Month Production  \
# 0         NaN                   NaN                          0          0
# 1         NaN                5422.0                          4          0
# 2         NaN                   NaN                          0          0
# 3         NaN                5699.0                         12          0
# 4         NaN                   NaN                          0          0
#
#   Volume  Code On Hand End of Month Formation Production Volume.1  Code.1
# 0    NaN   NaN                    0                    0      NaN     NaN
# 1    NaN   NaN                    4                    0      NaN     NaN
# 2    NaN   NaN                    0                    0      NaN     NaN
# 3    NaN   NaN                   12                  206      206     3.0
# 4    NaN   NaN                    0                    0      NaN     NaN

# %%
production.District.value_counts()
# Out:
# 10    1572
# 09    1088
# 08     466
# 7B       6
# 05       1
# Name: District, dtype: int64

# %% [markdown]
# ## Transform RRC

# %% [markdown]
# ### Filter to District

# %%
#converting data field to string to handle varying schema interpreations 
#(certain months field will be interpreted as float and string depending sample rows pandas uses

production = production.loc[production['District'].astype(str).isin(['8.0', '08', '8'])]

# %%
production
# Out:
#     Multiple Reports Lease Type District  RRC Identifier          Field Name  \
# 7                NaN        Oil       08         32907.0        ARMER (TUBB)
# 8                NaN        Oil       08         20550.0        ARMER (6350)
# 9                NaN        Oil       08         45314.0        ARMER (6350)
# 10               NaN        Oil       08         48393.0        ARMER (6350)
# 11               NaN        Oil       08         49425.0        ARMER (6350)
# ..               ...        ...      ...             ...                 ...
# 472              NaN        Gas       08        160203.0  WADDELL (GRAYBURG)
# 473              NaN        Gas       08        190864.0  WADDELL (GRAYBURG)
# 474              NaN        Gas       08        190926.0  WADDELL (GRAYBURG)
# 475              NaN        Gas       08        205775.0  WADDELL (GRAYBURG)
# 476              NaN        Oil       08         20361.0   -Y-, SOUTH (TUBB)
#
#                       Lease Name Gas Well ID Lease Total  \
# 7     MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 8    MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 9                 RAYDEN MCCAMEY         NaN         NaN
# 10                    LANDLUBBER         NaN         NaN
# 11                  6 POUNDER NE         NaN         NaN
# ..                           ...         ...         ...
# 472                WADDELL, W.N.       310           NaN
# 473                WADDELL, W.N.       890           NaN
# 474                WADDELL, W.N.       293           NaN
# 475               WADDELL, W. N.      1200           NaN
# 476  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production Volume  Code  \
# 7                  7024.0                        206         25    NaN   NaN
# 8                  7024.0                         78          0    NaN   NaN
# 9                     NaN                        452        111    164   1.0
# 10                 8026.0                      2,356      8,839  9,146   0.0
# 11                 8026.0                        446      1,057  1,195   0.0
# ..                    ...                        ...        ...    ...   ...
# 472                8988.0                          0          0    NaN   NaN
# 473                8988.0                          0          0    NaN   NaN
# 474                3501.0                         22         20     35   1.0
# 475                8092.0                         14         34     36   1.0
# 476                3803.0                          0          0    NaN   NaN
#
#     On Hand End of Month Formation Production Volume.1  Code.1
# 7                    231                    0      NaN     NaN
# 8                     78                    0      NaN     NaN
# 9                    399                2,214    2,214     2.0
# 10                 2,049               23,545   23,545     2.0
# 11                   308                5,160    5,160     2.0
# ..                   ...                  ...      ...     ...
# 472                    0                    0      NaN     NaN
# 473                    0                    0      NaN     NaN
# 474                    7                  244      244     2.0
# 475                   12                  524      524     2.0
# 476                    0                    0      NaN     NaN
#
# [466 rows x 17 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466 entries, 7 to 476
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Multiple Reports            19 non-null     object
#  1   Lease Type                  411 non-null    object
#  2   District                    466 non-null    object
#  3   RRC Identifier              466 non-null    float64
#  4   Field Name                  466 non-null    object
#  5   Lease Name                  466 non-null    object
#  6   Gas Well ID                 236 non-null    object
#  7   Lease Total                 14 non-null     object
#  8   Commingle Permit No.        278 non-null    float64
#  9   On Hand Beginning of Month  464 non-null    object
#  10  Production                  466 non-null    object
#  11  Volume                      215 non-null    object
#  12  Code                        215 non-null    float64
#  13  On Hand End of Month        466 non-null    object
#  14  Formation Production        426 non-null    object
#  15  Volume.1                    286 non-null    object
#  16  Code.1                      286 non-null    float64
# dtypes: float64(4), object(13)
# memory usage: 65.5+ KB

# %% [markdown]
# ### Clean Oil Production Columns and Convert to Int

# %%
production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
# Out:
# /var/folders/sj/kb7kr7w572z54pgv0pftb9v00000gn/T/ipykernel_40964/1394010457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
# /var/folders/sj/kb7kr7w572z54pgv0pftb9v00000gn/T/ipykernel_40964/1394010457.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))

# %% [markdown]
# ### Rename Volume to rrc_oil_volume

# %%
production.rename(columns = {'Volume': 'rrc_oil_volume'}, inplace = True)
production.rename(columns = {'Volume.1': 'rrc_gas_volume'}, inplace = True)
# Out:
# /Users/Mishaun_Bhakta/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
production['rrc_oil_volume'].sum()
production['rrc_gas_volume'].sum()
# Out:
# 431732
# 1667263

# %% [markdown]
# ### Normalize Field and Reservoir Names with Text Cleaning

# %%
production["Normalized_Field_Name"] = production['Field Name'].dropna()\
                                                            .apply(lambda x: str(x).split('(')[0]\
                                                                                    .split(',')[0]\
                                                                                    .strip())

# %%
production["Normalized_Reservoir_Name"] = production['Field Name'].dropna()\
                                        .apply(lambda x: str(x).split('(')[-1]\
                                                               .strip().replace(')',''))

# %% [markdown]
# ### Get Date from Production File

# %%
def get_date_from_csv(filepath, col_number, row_number):
    str_date = pd.read_csv(filepath, usecols = [col_number]).iloc[row_number].values[0]
    return str_date.strip()

# %%
get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1)
# Out:
# 'Apr 2021'

# %% [markdown]
# ### Add Production Date to Production Data Frame

# %%
production.insert(0, 'Date', get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1))

# %%
production
# Out:
#          Date Multiple Reports Lease Type District  RRC Identifier  \
# 7    Apr 2021              NaN        Oil       08         32907.0
# 8    Apr 2021              NaN        Oil       08         20550.0
# 9    Apr 2021              NaN        Oil       08         45314.0
# 10   Apr 2021              NaN        Oil       08         48393.0
# 11   Apr 2021              NaN        Oil       08         49425.0
# ..        ...              ...        ...      ...             ...
# 472  Apr 2021              NaN        Gas       08        160203.0
# 473  Apr 2021              NaN        Gas       08        190864.0
# 474  Apr 2021              NaN        Gas       08        190926.0
# 475  Apr 2021              NaN        Gas       08        205775.0
# 476  Apr 2021              NaN        Oil       08         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 7          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 8          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 9          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 10         ARMER (6350)                   LANDLUBBER         NaN         NaN
# 11         ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 472  WADDELL (GRAYBURG)                WADDELL, W.N.       310           NaN
# 473  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 474  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 475  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 476   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 7                  7024.0                        206         25
# 8                  7024.0                         78          0
# 9                     NaN                        452        111
# 10                 8026.0                      2,356      8,839
# 11                 8026.0                        446      1,057
# ..                    ...                        ...        ...
# 472                8988.0                          0          0
# 473                8988.0                          0          0
# 474                3501.0                         22         20
# 475                8092.0                         14         34
# 476                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 7                 0   NaN                  231                    0
# 8                 0   NaN                   78                    0
# 9               164   1.0                  399                2,214
# 10             9146   0.0                2,049               23,545
# 11             1195   0.0                  308                5,160
# ..              ...   ...                  ...                  ...
# 472               0   NaN                    0                    0
# 473               0   NaN                    0                    0
# 474              35   1.0                    7                  244
# 475              36   1.0                   12                  524
# 476               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name
# 7                 0     NaN                 ARMER                      TUBB
# 8                 0     NaN                 ARMER                      6350
# 9              2214     2.0                 ARMER                      6350
# 10            23545     2.0                 ARMER                      6350
# 11             5160     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 472               0     NaN               WADDELL                  GRAYBURG
# 473               0     NaN               WADDELL                  GRAYBURG
# 474             244     2.0               WADDELL                  GRAYBURG
# 475             524     2.0               WADDELL                  GRAYBURG
# 476               0     NaN                   -Y-                      TUBB
#
# [466 rows x 20 columns]

# %% [markdown]
# ### Add columns for net production to Trust

# %%
production['Net Oil Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50
production['Net Oil Sales Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50 * 0.75

# %%
production['Net Gas Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50
production['Net Gas Sales Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50 * 0.75

# %%
production
# Out:
#          Date Multiple Reports Lease Type District  RRC Identifier  \
# 7    Apr 2021              NaN        Oil       08         32907.0
# 8    Apr 2021              NaN        Oil       08         20550.0
# 9    Apr 2021              NaN        Oil       08         45314.0
# 10   Apr 2021              NaN        Oil       08         48393.0
# 11   Apr 2021              NaN        Oil       08         49425.0
# ..        ...              ...        ...      ...             ...
# 472  Apr 2021              NaN        Gas       08        160203.0
# 473  Apr 2021              NaN        Gas       08        190864.0
# 474  Apr 2021              NaN        Gas       08        190926.0
# 475  Apr 2021              NaN        Gas       08        205775.0
# 476  Apr 2021              NaN        Oil       08         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 7          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 8          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 9          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 10         ARMER (6350)                   LANDLUBBER         NaN         NaN
# 11         ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 472  WADDELL (GRAYBURG)                WADDELL, W.N.       310           NaN
# 473  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 474  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 475  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 476   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 7                  7024.0                        206         25
# 8                  7024.0                         78          0
# 9                     NaN                        452        111
# 10                 8026.0                      2,356      8,839
# 11                 8026.0                        446      1,057
# ..                    ...                        ...        ...
# 472                8988.0                          0          0
# 473                8988.0                          0          0
# 474                3501.0                         22         20
# 475                8092.0                         14         34
# 476                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 7                 0   NaN                  231                    0
# 8                 0   NaN                   78                    0
# 9               164   1.0                  399                2,214
# 10             9146   0.0                2,049               23,545
# 11             1195   0.0                  308                5,160
# ..              ...   ...                  ...                  ...
# 472               0   NaN                    0                    0
# 473               0   NaN                    0                    0
# 474              35   1.0                    7                  244
# 475              36   1.0                   12                  524
# 476               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name  \
# 7                 0     NaN                 ARMER                      TUBB
# 8                 0     NaN                 ARMER                      6350
# 9              2214     2.0                 ARMER                      6350
# 10            23545     2.0                 ARMER                      6350
# 11             5160     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 472               0     NaN               WADDELL                  GRAYBURG
# 473               0     NaN               WADDELL                  GRAYBURG
# 474             244     2.0               WADDELL                  GRAYBURG
# 475             524     2.0               WADDELL                  GRAYBURG
# 476               0     NaN                   -Y-                      TUBB
#
#      Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 7                              0.0                                0.000
# 8                              0.0                                0.000
# 9                             82.0                               61.500
# 10                          4573.0                             3429.750
# 11                           597.5                              448.125
# ..                             ...                                  ...
# 472                            0.0                                0.000
# 473                            0.0                                0.000
# 474                           17.5                               13.125
# 475                           18.0                               13.500
# 476                            0.0                                0.000
#
#      Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 7                              0.0                                0.000
# 8                              0.0                                0.000
# 9                           1107.0                              830.250
# 10                         11772.5                             8829.375
# 11                          2580.0                             1935.000
# ..                             ...                                  ...
# 472                            0.0                                0.000
# 473                            0.0                                0.000
# 474                          122.0                               91.500
# 475                          262.0                              196.500
# 476                            0.0                                0.000
#
# [466 rows x 24 columns]

# %% [markdown]
# ### Write to File

# %%
production.to_csv(f'{processed_data_folder}/rrc_prod/{file_name}', index = False)

# %% [markdown]
# ## Aggregated EDA

# %%
production.groupby(['Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'})\
                                            .sort_values(by = 'rrc_oil_volume', ascending= False)\
                                            .head(15)
# Out:
#                        rrc_oil_volume
# Normalized_Field_Name
# SAND HILLS                     236789
# MONAHANS                        83549
# ARMER                           46415
# DUNE                            19709
# UNIVERSITY WADDELL              10092
# MARSTON RANCH                    9704
# KEYSTONE                         8828
# WADDELL                          7453
# RUNNING W                        3304
# CORDONA LAKE                     2113
# KERMIT                           1343
# LEA                               901
# SHAFTER LAKE                      835
# COWDEN                            361
# BLOCK 31                          178

# %%
production.groupby(['Normalized_Reservoir_Name', 'Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'}).sort_values(by = 'rrc_oil_volume', ascending= False).sort_index()
# Out:
#                                                  rrc_oil_volume
# Normalized_Reservoir_Name Normalized_Field_Name
# 6350                      ARMER                           46415
# 7900                      EDWARDS -04-                        0
# CLEAR FORK                LEA                               259
#                           MONAHANS                            0
#                           SAND HILLS                      62248
# CLEAR FORK 4070           SAND HILLS                        346
# CLEAR FORK, LOWER         MCKEE                               0
# CLEAR FORK, MID.          MCKEE                               0
# CLEARFORK                 MARSTON RANCH                    9704
#                           MONAHANS                        77626
#                           RM                                  0
# COLBY                     KEYSTONE                         1638
# CONSOLIDATED              KEYSTONE                         5750
# CORDONA LAKE              CORDONA LAKE                        0
# COWDEN, NORTH             COWDEN                            361
# DEV.                      CORDONA LAKE                     1826
# DEVONIAN                  CORDONA LAKE                      242
#                           UNIVERSITY WADDELL               9239
#                           WADDELL                           335
# DUNE                      DUNE                            19701
# ELLENBURGER               KERMIT                           1003
#                           SAND HILLS                        808
#                           UNIVERSITY WADDELL                  0
# GRAYBURG                  GOLDSMITH                           0
#                           WADDELL                           492
# HOLT                      RUNNING W                         114
#                           SAND HILLS                          0
# JUDKINS                   SAND HILLS                      12174
# KERMIT                    KERMIT                            165
# MCKEE                     BLOCK 27                            0
#                           KERMIT                            175
#                           RUNNING W                           0
# MCKNIGHT                  SAND HILLS                      40271
# MONAHANS, NORTH           MONAHANS                         5923
# ORDOVICIAN                SAND HILLS                          0
# PENN UPPER                BLOCK 31                          178
# PENN.                     G. P. M.                            0
#                           UNIVERSITY WADDELL                 31
# QUEEN                     GOLDSMITH                           0
# SAN ANDRES                C-BAR                               0
#                           DELL                              158
#                           KEYSTONE                         1440
#                           LEA                                41
#                           SHAFTER LAKE                      835
# SAN ANDRES CONS.          CRAWAR                              0
# SAN ANDRES, CON.          GOLDSMITH                           0
# SAN ANGELO                LEA                               601
#                           SAND HILLS                        436
# SAN ANGELO, UPPER         SAND HILLS                      24750
# TUBB                      -Y-                                 0
#                           ARMER                               0
#                           BLOCK B-21                          0
#                           RUNNING W                        1085
#                           SAND HILLS                      39355
# TUBB 4500                 CORDONA LAKE                       45
# WADDELL                   RUNNING W                        1115
#                           WADDELL                          6626
# WADDELL SD.               UNIVERSITY WADDELL                822
# WICHITA-ALBANY            RUNNING W                         990
#                           SAND HILLS                      27978
# WICHITA-ALBANY, GAS       SAND HILLS                        379
# WOJCIK-MCELROY            SAND HILLS                        210
# WOLFCAMP                  DUNE                                8
#                           MCKEE                               0
#                           SAND HILLS                      27834
# YATES                     KERMIT                              0
