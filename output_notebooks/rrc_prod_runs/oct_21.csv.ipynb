# %%
import pandas as pd
import datetime as dt

pd.options.display.max_columns=1000
pd.options.display.max_rows = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %run configs.ipynb

# %%
# parameter cell
file_name = 'oct_21.csv'

# %%
# Parameters
file_name = "oct_21.csv"

# %% [markdown]
# # RRC Prod

# %% [markdown]
# ## Ingest

# %%
production = pd.read_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', header = 5)

# %%
production.head()
# Out:
#   Multiple Reports Lease Type  District  RRC Identifier    Field Name  \
# 0              NaN        Oil       8.0         32907.0  ARMER (TUBB)
# 1              NaN        Oil       8.0         20550.0  ARMER (6350)
# 2              NaN        Oil       8.0         45314.0  ARMER (6350)
# 3                Y        Oil       8.0         48393.0  ARMER (6350)
# 4              NaN        Oil       8.0         49425.0  ARMER (6350)
#
#                     Lease Name Gas Well ID Lease Total  Commingle Permit No.  \
# 0   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN                7024.0
# 1  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN                7024.0
# 2               RAYDEN MCCAMEY         NaN         NaN                   NaN
# 3                   LANDLUBBER         NaN         NaN                8026.0
# 4                 6 POUNDER NE         NaN         NaN                8026.0
#
#   On Hand Beginning of Month Production Volume  Code On Hand End of Month  \
# 0                        140         26    NaN   NaN                  166
# 1                         18          0    NaN   NaN                   18
# 2                        261         87    183   1.0                  165
# 3                      1,721      7,857  8,126   0.0                1,452
# 4                        507        870  1,184   0.0                  193
#
#   Formation Production Volume.1  Code.1
# 0                    0      NaN     NaN
# 1                    0      NaN     NaN
# 2                1,699    1,699     2.0
# 3               19,723   19,723     2.0
# 4                3,832    3,832     2.0

# %% [markdown]
# ## Transform RRC

# %% [markdown]
# ### Filter to District

# %%
#converting data field to string to handle varying schema interpreations 
#(certain months field will be interpreted as float and string depending sample rows pandas uses

production = production.loc[production['District'].astype(str).isin(['8.0', '08', '8'])]

# %%
production
# Out:
#     Multiple Reports Lease Type  District  RRC Identifier          Field Name  \
# 0                NaN        Oil       8.0         32907.0        ARMER (TUBB)
# 1                NaN        Oil       8.0         20550.0        ARMER (6350)
# 2                NaN        Oil       8.0         45314.0        ARMER (6350)
# 3                  Y        Oil       8.0         48393.0        ARMER (6350)
# 4                NaN        Oil       8.0         49425.0        ARMER (6350)
# ..               ...        ...       ...             ...                 ...
# 501              NaN        Gas       8.0        147187.0  WADDELL (GRAYBURG)
# 503              NaN        Gas       8.0        190864.0  WADDELL (GRAYBURG)
# 504              NaN        Gas       8.0        190926.0  WADDELL (GRAYBURG)
# 506              NaN        Gas       8.0        205775.0  WADDELL (GRAYBURG)
# 508              NaN        Oil       8.0         20361.0   -Y-, SOUTH (TUBB)
#
#                       Lease Name Gas Well ID Lease Total  \
# 0     MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1    MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2                 RAYDEN MCCAMEY         NaN         NaN
# 3                     LANDLUBBER         NaN         NaN
# 4                   6 POUNDER NE         NaN         NaN
# ..                           ...         ...         ...
# 501                WADDELL, W.N.       859           NaN
# 503                WADDELL, W.N.       890           NaN
# 504                WADDELL, W.N.       293           NaN
# 506               WADDELL, W. N.      1200           NaN
# 508  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production Volume  Code  \
# 0                  7024.0                        140         26    NaN   NaN
# 1                  7024.0                         18          0    NaN   NaN
# 2                     NaN                        261         87    183   1.0
# 3                  8026.0                      1,721      7,857  8,126   0.0
# 4                  8026.0                        507        870  1,184   0.0
# ..                    ...                        ...        ...    ...   ...
# 501                8988.0                          8         31     37   1.0
# 503                8988.0                          0          0    NaN   NaN
# 504                3501.0                          8         31     37   1.0
# 506                8092.0                          8         31     37   1.0
# 508                3803.0                          0          0    NaN   NaN
#
#     On Hand End of Month Formation Production Volume.1  Code.1
# 0                    166                    0      NaN     NaN
# 1                     18                    0      NaN     NaN
# 2                    165                1,699    1,699     2.0
# 3                  1,452               19,723   19,723     2.0
# 4                    193                3,832    3,832     2.0
# ..                   ...                  ...      ...     ...
# 501                    2                  736      736     2.0
# 503                    0                    0      NaN     NaN
# 504                    2                  606      606     2.0
# 506                    2                  784      784     2.0
# 508                    0                    0      NaN     NaN
#
# [452 rows x 17 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 508
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Multiple Reports            113 non-null    object
#  1   Lease Type                  407 non-null    object
#  2   District                    452 non-null    float64
#  3   RRC Identifier              452 non-null    float64
#  4   Field Name                  452 non-null    object
#  5   Lease Name                  452 non-null    object
#  6   Gas Well ID                 232 non-null    object
#  7   Lease Total                 12 non-null     object
#  8   Commingle Permit No.        263 non-null    float64
#  9   On Hand Beginning of Month  400 non-null    object
#  10  Production                  452 non-null    object
#  11  Volume                      180 non-null    object
#  12  Code                        180 non-null    float64
#  13  On Hand End of Month        452 non-null    object
#  14  Formation Production        416 non-null    object
#  15  Volume.1                    231 non-null    object
#  16  Code.1                      231 non-null    float64
# dtypes: float64(5), object(12)
# memory usage: 63.6+ KB

# %% [markdown]
# ### Clean Oil Production Columns and Convert to Int

# %%
production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))

# %% [markdown]
# ### Rename Volume to rrc_oil_volume

# %%
production.rename(columns = {'Volume': 'rrc_oil_volume'}, inplace = True)
production.rename(columns = {'Volume.1': 'rrc_gas_volume'}, inplace = True)

# %%
production['rrc_oil_volume'].sum()
production['rrc_gas_volume'].sum()
# Out:
# 361442
# 1252917

# %% [markdown]
# ### Normalize Field and Reservoir Names with Text Cleaning

# %%
production["Normalized_Field_Name"] = production['Field Name'].dropna()\
                                                            .apply(lambda x: str(x).split('(')[0]\
                                                                                    .split(',')[0]\
                                                                                    .strip())

# %%
production["Normalized_Reservoir_Name"] = production['Field Name'].dropna()\
                                        .apply(lambda x: str(x).split('(')[-1]\
                                                               .strip().replace(')',''))

# %% [markdown]
# ### Get Date from Production File

# %%
def get_date_from_csv(filepath, col_number, row_number):
    str_date = pd.read_csv(filepath, usecols = [col_number]).iloc[row_number].values[0]
    return str_date.strip()

# %%
get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1)
# Out:
# 'Oct 2021'

# %% [markdown]
# ### Add Production Date to Production Data Frame

# %%
production.insert(0, 'Date', get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1))

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Oct 2021              NaN        Oil       8.0         32907.0
# 1    Oct 2021              NaN        Oil       8.0         20550.0
# 2    Oct 2021              NaN        Oil       8.0         45314.0
# 3    Oct 2021                Y        Oil       8.0         48393.0
# 4    Oct 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 501  Oct 2021              NaN        Gas       8.0        147187.0
# 503  Oct 2021              NaN        Gas       8.0        190864.0
# 504  Oct 2021              NaN        Gas       8.0        190926.0
# 506  Oct 2021              NaN        Gas       8.0        205775.0
# 508  Oct 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 501  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 503  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 504  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 506  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 508   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        140         26
# 1                  7024.0                         18          0
# 2                     NaN                        261         87
# 3                  8026.0                      1,721      7,857
# 4                  8026.0                        507        870
# ..                    ...                        ...        ...
# 501                8988.0                          8         31
# 503                8988.0                          0          0
# 504                3501.0                          8         31
# 506                8092.0                          8         31
# 508                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  166                    0
# 1                 0   NaN                   18                    0
# 2               183   1.0                  165                1,699
# 3              8126   0.0                1,452               19,723
# 4              1184   0.0                  193                3,832
# ..              ...   ...                  ...                  ...
# 501              37   1.0                    2                  736
# 503               0   NaN                    0                    0
# 504              37   1.0                    2                  606
# 506              37   1.0                    2                  784
# 508               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              1699     2.0                 ARMER                      6350
# 3             19723     2.0                 ARMER                      6350
# 4              3832     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 501             736     2.0               WADDELL                  GRAYBURG
# 503               0     NaN               WADDELL                  GRAYBURG
# 504             606     2.0               WADDELL                  GRAYBURG
# 506             784     2.0               WADDELL                  GRAYBURG
# 508               0     NaN                   -Y-                      TUBB
#
# [452 rows x 20 columns]

# %% [markdown]
# ### Add columns for net production to Trust

# %%
production['Net Oil Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50
production['Net Oil Sales Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50 * 0.75

# %%
production['Net Gas Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50
production['Net Gas Sales Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50 * 0.75

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Oct 2021              NaN        Oil       8.0         32907.0
# 1    Oct 2021              NaN        Oil       8.0         20550.0
# 2    Oct 2021              NaN        Oil       8.0         45314.0
# 3    Oct 2021                Y        Oil       8.0         48393.0
# 4    Oct 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 501  Oct 2021              NaN        Gas       8.0        147187.0
# 503  Oct 2021              NaN        Gas       8.0        190864.0
# 504  Oct 2021              NaN        Gas       8.0        190926.0
# 506  Oct 2021              NaN        Gas       8.0        205775.0
# 508  Oct 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 501  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 503  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 504  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 506  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 508   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        140         26
# 1                  7024.0                         18          0
# 2                     NaN                        261         87
# 3                  8026.0                      1,721      7,857
# 4                  8026.0                        507        870
# ..                    ...                        ...        ...
# 501                8988.0                          8         31
# 503                8988.0                          0          0
# 504                3501.0                          8         31
# 506                8092.0                          8         31
# 508                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  166                    0
# 1                 0   NaN                   18                    0
# 2               183   1.0                  165                1,699
# 3              8126   0.0                1,452               19,723
# 4              1184   0.0                  193                3,832
# ..              ...   ...                  ...                  ...
# 501              37   1.0                    2                  736
# 503               0   NaN                    0                    0
# 504              37   1.0                    2                  606
# 506              37   1.0                    2                  784
# 508               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name  \
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              1699     2.0                 ARMER                      6350
# 3             19723     2.0                 ARMER                      6350
# 4              3832     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 501             736     2.0               WADDELL                  GRAYBURG
# 503               0     NaN               WADDELL                  GRAYBURG
# 504             606     2.0               WADDELL                  GRAYBURG
# 506             784     2.0               WADDELL                  GRAYBURG
# 508               0     NaN                   -Y-                      TUBB
#
#      Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                             91.5                               68.625
# 3                           4063.0                             3047.250
# 4                            592.0                              444.000
# ..                             ...                                  ...
# 501                           18.5                               13.875
# 503                            0.0                                0.000
# 504                           18.5                               13.875
# 506                           18.5                               13.875
# 508                            0.0                                0.000
#
#      Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                            849.5                              637.125
# 3                           9861.5                             7396.125
# 4                           1916.0                             1437.000
# ..                             ...                                  ...
# 501                          368.0                              276.000
# 503                            0.0                                0.000
# 504                          303.0                              227.250
# 506                          392.0                              294.000
# 508                            0.0                                0.000
#
# [452 rows x 24 columns]

# %% [markdown]
# ### Write to File

# %%
production.to_csv(f'{processed_data_folder}/rrc_prod/{file_name}', index = False)

# %% [markdown]
# ## Aggregated EDA

# %%
production.groupby(['Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'})\
                                            .sort_values(by = 'rrc_oil_volume', ascending= False)\
                                            .head(15)
# Out:
#                        rrc_oil_volume
# Normalized_Field_Name
# SAND HILLS                     213134
# MONAHANS                        73275
# ARMER                           31688
# DUNE                            17158
# MARSTON RANCH                    9117
# RUNNING W                        5582
# WADDELL                          4810
# UNIVERSITY WADDELL               2425
# CORDONA LAKE                     2124
# LEA                              1429
# BLOCK 31                          530
# DELL                              170
# SHAFTER LAKE                        0
# RM                                  0
# MCKEE                               0

# %%
production.groupby(['Normalized_Reservoir_Name', 'Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'}).sort_values(by = 'rrc_oil_volume', ascending= False).sort_index()
# Out:
#                                                  rrc_oil_volume
# Normalized_Reservoir_Name Normalized_Field_Name
# 6350                      ARMER                           31688
# 7900                      EDWARDS -04-                        0
# CLEAR FORK                LEA                               331
#                           MONAHANS                            0
#                           SAND HILLS                      39232
# CLEAR FORK 4070           SAND HILLS                        642
# CLEAR FORK, LOWER         MCKEE                               0
# CLEAR FORK, MID.          MCKEE                               0
# CLEARFORK                 MARSTON RANCH                    9117
#                           MONAHANS                        67562
#                           RM                                  0
# COLBY                     KEYSTONE                            0
# CONSOLIDATED              KEYSTONE                            0
# CORDONA LAKE              CORDONA LAKE                       92
# COWDEN, NORTH             COWDEN                              0
# DEV.                      CORDONA LAKE                     1832
# DEVONIAN                  CORDONA LAKE                      143
#                           UNIVERSITY WADDELL               1348
#                           WADDELL                           202
# DUNE                      DUNE                            17144
# ELLENBURGER               KERMIT                              0
#                           SAND HILLS                        954
#                           UNIVERSITY WADDELL                  0
# GLORIETA                  MONAHANS                          663
# GRAYBURG                  GOLDSMITH                           0
#                           WADDELL                           354
# HOLT                      RUNNING W                          25
#                           SAND HILLS                          0
# JUDKINS                   SAND HILLS                        303
# KERMIT                    KERMIT                              0
# MCKEE                     BLOCK 27                            0
#                           KERMIT                              0
#                           RUNNING W                           0
# MCKNIGHT                  SAND HILLS                      47479
# MONAHANS, NORTH           MONAHANS                         5050
# ORDOVICIAN                SAND HILLS                          0
# PENN UPPER                BLOCK 31                          530
# PENN.                     G. P. M.                            0
#                           UNIVERSITY WADDELL                 56
# QUEEN                     GOLDSMITH                           0
# SAN ANDRES                C-BAR                               0
#                           DELL                              170
#                           KEYSTONE                            0
#                           LEA                                84
#                           SHAFTER LAKE                        0
# SAN ANDRES CONS.          CRAWAR                              0
# SAN ANDRES, CON.          GOLDSMITH                           0
# SAN ANGELO                LEA                              1014
#                           SAND HILLS                       1952
# SAN ANGELO, UPPER         SAND HILLS                      38843
# TUBB                      -Y-                                 0
#                           ARMER                               0
#                           BLOCK B-21                          0
#                           RUNNING W                        1735
#                           SAND HILLS                      42940
# TUBB 4500                 CORDONA LAKE                       57
# WADDELL                   RUNNING W                        3184
#                           WADDELL                          4254
# WADDELL SD.               UNIVERSITY WADDELL               1021
# WICHITA-ALBANY            RUNNING W                         638
#                           SAND HILLS                      23051
# WICHITA-ALBANY, GAS       SAND HILLS                        841
# WOJCIK-MCELROY            SAND HILLS                        289
# WOLFCAMP                  DUNE                               14
#                           MCKEE                               0
#                           SAND HILLS                      16608
# YATES                     KERMIT                              0
