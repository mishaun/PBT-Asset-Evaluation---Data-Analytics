# %%
import pandas as pd
import datetime as dt

pd.options.display.max_columns=1000
pd.options.display.max_rows = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %run configs.ipynb

# %%
# parameter cell
file_name = 'oct_21.csv'

# %%
# Parameters
file_name = "july_21.csv"

# %% [markdown]
# # RRC Prod

# %% [markdown]
# ## Ingest

# %%
production = pd.read_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', header = 5)

# %%
production.head()
# Out:
#   Multiple Reports Lease Type  District  RRC Identifier    Field Name  \
# 0              NaN        Oil       8.0         32907.0  ARMER (TUBB)
# 1              NaN        Oil       8.0         20550.0  ARMER (6350)
# 2              NaN        Oil       8.0         45314.0  ARMER (6350)
# 3              NaN        Oil       8.0         48393.0  ARMER (6350)
# 4              NaN        Oil       8.0         49425.0  ARMER (6350)
#
#                     Lease Name Gas Well ID Lease Total  Commingle Permit No.  \
# 0   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN                7024.0
# 1  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN                7024.0
# 2               RAYDEN MCCAMEY         NaN         NaN                   NaN
# 3                   LANDLUBBER         NaN         NaN                8026.0
# 4                 6 POUNDER NE         NaN         NaN                8026.0
#
#   On Hand Beginning of Month Production Volume  Code On Hand End of Month  \
# 0                        185         37    NaN   NaN                  222
# 1                         39          0    NaN   NaN                   39
# 2                        267         91    175   1.0                  183
# 3                      2,013      8,947  9,078   0.0                1,882
# 4                        364      1,581  1,460   0.0                  485
#
#   Formation Production Volume.1  Code.1
# 0                    0      NaN     NaN
# 1                    0      NaN     NaN
# 2                2,165    2,165     2.0
# 3               22,367   22,367     2.0
# 4                4,933    4,933     2.0

# %% [markdown]
# ## Transform RRC

# %% [markdown]
# ### Filter to District

# %%
#converting data field to string to handle varying schema interpreations 
#(certain months field will be interpreted as float and string depending sample rows pandas uses

production = production.loc[production['District'].astype(str).isin(['8.0', '08', '8'])]

# %%
production
# Out:
#     Multiple Reports Lease Type  District  RRC Identifier          Field Name  \
# 0                NaN        Oil       8.0         32907.0        ARMER (TUBB)
# 1                NaN        Oil       8.0         20550.0        ARMER (6350)
# 2                NaN        Oil       8.0         45314.0        ARMER (6350)
# 3                NaN        Oil       8.0         48393.0        ARMER (6350)
# 4                NaN        Oil       8.0         49425.0        ARMER (6350)
# ..               ...        ...       ...             ...                 ...
# 383              NaN        Gas       8.0        147187.0  WADDELL (GRAYBURG)
# 384              NaN        Gas       8.0        190864.0  WADDELL (GRAYBURG)
# 385              NaN        Gas       8.0        190926.0  WADDELL (GRAYBURG)
# 386              NaN        Gas       8.0        205775.0  WADDELL (GRAYBURG)
# 387              NaN        Oil       8.0         20361.0   -Y-, SOUTH (TUBB)
#
#                       Lease Name Gas Well ID Lease Total  \
# 0     MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1    MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2                 RAYDEN MCCAMEY         NaN         NaN
# 3                     LANDLUBBER         NaN         NaN
# 4                   6 POUNDER NE         NaN         NaN
# ..                           ...         ...         ...
# 383                WADDELL, W.N.       859           NaN
# 384                WADDELL, W.N.       890           NaN
# 385                WADDELL, W.N.       293           NaN
# 386               WADDELL, W. N.      1200           NaN
# 387  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production Volume  Code  \
# 0                  7024.0                        185         37    NaN   NaN
# 1                  7024.0                         39          0    NaN   NaN
# 2                     NaN                        267         91    175   1.0
# 3                  8026.0                      2,013      8,947  9,078   0.0
# 4                  8026.0                        364      1,581  1,460   0.0
# ..                    ...                        ...        ...    ...   ...
# 383                8988.0                          4         24     21   1.0
# 384                8988.0                          0          0    NaN   NaN
# 385                3501.0                          4         25     22   1.0
# 386                8092.0                          4         25     22   1.0
# 387                3803.0                          0          0    NaN   NaN
#
#     On Hand End of Month Formation Production Volume.1  Code.1
# 0                    222                    0      NaN     NaN
# 1                     39                    0      NaN     NaN
# 2                    183                2,165    2,165     2.0
# 3                  1,882               22,367   22,367     2.0
# 4                    485                4,933    4,933     2.0
# ..                   ...                  ...      ...     ...
# 383                    7                  436      436     2.0
# 384                    0                    0      NaN     NaN
# 385                    7                   12       12     2.0
# 386                    7                  240      240     2.0
# 387                    0                    0      NaN     NaN
#
# [385 rows x 17 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 385 entries, 0 to 387
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Multiple Reports            12 non-null     object
#  1   Lease Type                  332 non-null    object
#  2   District                    385 non-null    float64
#  3   RRC Identifier              385 non-null    float64
#  4   Field Name                  385 non-null    object
#  5   Lease Name                  385 non-null    object
#  6   Gas Well ID                 181 non-null    object
#  7   Lease Total                 13 non-null     object
#  8   Commingle Permit No.        258 non-null    float64
#  9   On Hand Beginning of Month  385 non-null    object
#  10  Production                  385 non-null    object
#  11  Volume                      194 non-null    object
#  12  Code                        194 non-null    float64
#  13  On Hand End of Month        385 non-null    object
#  14  Formation Production        338 non-null    object
#  15  Volume.1                    231 non-null    object
#  16  Code.1                      231 non-null    float64
# dtypes: float64(5), object(12)
# memory usage: 54.1+ KB

# %% [markdown]
# ### Clean Oil Production Columns and Convert to Int

# %%
production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))

# %% [markdown]
# ### Rename Volume to rrc_oil_volume

# %%
production.rename(columns = {'Volume': 'rrc_oil_volume'}, inplace = True)
production.rename(columns = {'Volume.1': 'rrc_gas_volume'}, inplace = True)

# %%
production['rrc_oil_volume'].sum()
production['rrc_gas_volume'].sum()
# Out:
# 395910
# 1400233

# %% [markdown]
# ### Normalize Field and Reservoir Names with Text Cleaning

# %%
production["Normalized_Field_Name"] = production['Field Name'].dropna()\
                                                            .apply(lambda x: str(x).split('(')[0]\
                                                                                    .split(',')[0]\
                                                                                    .strip())

# %%
production["Normalized_Reservoir_Name"] = production['Field Name'].dropna()\
                                        .apply(lambda x: str(x).split('(')[-1]\
                                                               .strip().replace(')',''))

# %% [markdown]
# ### Get Date from Production File

# %%
def get_date_from_csv(filepath, col_number, row_number):
    str_date = pd.read_csv(filepath, usecols = [col_number]).iloc[row_number].values[0]
    return str_date.strip()

# %%
get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1)
# Out:
# 'Jul 2021'

# %% [markdown]
# ### Add Production Date to Production Data Frame

# %%
production.insert(0, 'Date', get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1))

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Jul 2021              NaN        Oil       8.0         32907.0
# 1    Jul 2021              NaN        Oil       8.0         20550.0
# 2    Jul 2021              NaN        Oil       8.0         45314.0
# 3    Jul 2021              NaN        Oil       8.0         48393.0
# 4    Jul 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 383  Jul 2021              NaN        Gas       8.0        147187.0
# 384  Jul 2021              NaN        Gas       8.0        190864.0
# 385  Jul 2021              NaN        Gas       8.0        190926.0
# 386  Jul 2021              NaN        Gas       8.0        205775.0
# 387  Jul 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 383  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 384  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 385  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 386  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 387   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        185         37
# 1                  7024.0                         39          0
# 2                     NaN                        267         91
# 3                  8026.0                      2,013      8,947
# 4                  8026.0                        364      1,581
# ..                    ...                        ...        ...
# 383                8988.0                          4         24
# 384                8988.0                          0          0
# 385                3501.0                          4         25
# 386                8092.0                          4         25
# 387                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  222                    0
# 1                 0   NaN                   39                    0
# 2               175   1.0                  183                2,165
# 3              9078   0.0                1,882               22,367
# 4              1460   0.0                  485                4,933
# ..              ...   ...                  ...                  ...
# 383              21   1.0                    7                  436
# 384               0   NaN                    0                    0
# 385              22   1.0                    7                   12
# 386              22   1.0                    7                  240
# 387               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              2165     2.0                 ARMER                      6350
# 3             22367     2.0                 ARMER                      6350
# 4              4933     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 383             436     2.0               WADDELL                  GRAYBURG
# 384               0     NaN               WADDELL                  GRAYBURG
# 385              12     2.0               WADDELL                  GRAYBURG
# 386             240     2.0               WADDELL                  GRAYBURG
# 387               0     NaN                   -Y-                      TUBB
#
# [385 rows x 20 columns]

# %% [markdown]
# ### Add columns for net production to Trust

# %%
production['Net Oil Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50
production['Net Oil Sales Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50 * 0.75

# %%
production['Net Gas Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50
production['Net Gas Sales Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50 * 0.75

# %%
production
# Out:
#          Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0    Jul 2021              NaN        Oil       8.0         32907.0
# 1    Jul 2021              NaN        Oil       8.0         20550.0
# 2    Jul 2021              NaN        Oil       8.0         45314.0
# 3    Jul 2021              NaN        Oil       8.0         48393.0
# 4    Jul 2021              NaN        Oil       8.0         49425.0
# ..        ...              ...        ...       ...             ...
# 383  Jul 2021              NaN        Gas       8.0        147187.0
# 384  Jul 2021              NaN        Gas       8.0        190864.0
# 385  Jul 2021              NaN        Gas       8.0        190926.0
# 386  Jul 2021              NaN        Gas       8.0        205775.0
# 387  Jul 2021              NaN        Oil       8.0         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 0          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3          ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4          ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 383  WADDELL (GRAYBURG)                WADDELL, W.N.       859           NaN
# 384  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 385  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 386  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 387   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 0                  7024.0                        185         37
# 1                  7024.0                         39          0
# 2                     NaN                        267         91
# 3                  8026.0                      2,013      8,947
# 4                  8026.0                        364      1,581
# ..                    ...                        ...        ...
# 383                8988.0                          4         24
# 384                8988.0                          0          0
# 385                3501.0                          4         25
# 386                8092.0                          4         25
# 387                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 0                 0   NaN                  222                    0
# 1                 0   NaN                   39                    0
# 2               175   1.0                  183                2,165
# 3              9078   0.0                1,882               22,367
# 4              1460   0.0                  485                4,933
# ..              ...   ...                  ...                  ...
# 383              21   1.0                    7                  436
# 384               0   NaN                    0                    0
# 385              22   1.0                    7                   12
# 386              22   1.0                    7                  240
# 387               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name  \
# 0                 0     NaN                 ARMER                      TUBB
# 1                 0     NaN                 ARMER                      6350
# 2              2165     2.0                 ARMER                      6350
# 3             22367     2.0                 ARMER                      6350
# 4              4933     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 383             436     2.0               WADDELL                  GRAYBURG
# 384               0     NaN               WADDELL                  GRAYBURG
# 385              12     2.0               WADDELL                  GRAYBURG
# 386             240     2.0               WADDELL                  GRAYBURG
# 387               0     NaN                   -Y-                      TUBB
#
#      Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                             87.5                               65.625
# 3                           4539.0                             3404.250
# 4                            730.0                              547.500
# ..                             ...                                  ...
# 383                           10.5                                7.875
# 384                            0.0                                0.000
# 385                           11.0                                8.250
# 386                           11.0                                8.250
# 387                            0.0                                0.000
#
#      Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 0                              0.0                                0.000
# 1                              0.0                                0.000
# 2                           1082.5                              811.875
# 3                          11183.5                             8387.625
# 4                           2466.5                             1849.875
# ..                             ...                                  ...
# 383                          218.0                              163.500
# 384                            0.0                                0.000
# 385                            6.0                                4.500
# 386                          120.0                               90.000
# 387                            0.0                                0.000
#
# [385 rows x 24 columns]

# %% [markdown]
# ### Write to File

# %%
production.to_csv(f'{processed_data_folder}/rrc_prod/{file_name}', index = False)

# %% [markdown]
# ## Aggregated EDA

# %%
production.groupby(['Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'})\
                                            .sort_values(by = 'rrc_oil_volume', ascending= False)\
                                            .head(15)
# Out:
#                        rrc_oil_volume
# Normalized_Field_Name
# SAND HILLS                     232428
# MONAHANS                        69427
# ARMER                           40953
# DUNE                            17928
# UNIVERSITY WADDELL              10130
# MARSTON RANCH                    8893
# RUNNING W                        6196
# WADDELL                          6027
# CORDONA LAKE                     2713
# LEA                              1048
# G. P. M.                          167
# RM                                  0
# MCKEE                               0
# -Y-                                 0
# DELL                                0

# %%
production.groupby(['Normalized_Reservoir_Name', 'Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'}).sort_values(by = 'rrc_oil_volume', ascending= False).sort_index()
# Out:
#                                                  rrc_oil_volume
# Normalized_Reservoir_Name Normalized_Field_Name
# 6350                      ARMER                           40953
# 7900                      EDWARDS -04-                        0
# CLEAR FORK                LEA                               277
#                           MONAHANS                            0
#                           SAND HILLS                      47882
# CLEAR FORK 4070           SAND HILLS                        422
# CLEAR FORK, LOWER         MCKEE                               0
# CLEAR FORK, MID.          MCKEE                               0
# CLEARFORK                 MARSTON RANCH                    8893
#                           MONAHANS                        64436
#                           RM                                  0
# CORDONA LAKE              CORDONA LAKE                      223
# DEV.                      CORDONA LAKE                     1878
# DEVONIAN                  CORDONA LAKE                      210
#                           UNIVERSITY WADDELL               9302
#                           WADDELL                           225
# DUNE                      DUNE                            17902
# ELLENBURGER               SAND HILLS                       1224
#                           UNIVERSITY WADDELL                  0
# GRAYBURG                  WADDELL                           412
# HOLT                      RUNNING W                          81
#                           SAND HILLS                          0
# JUDKINS                   SAND HILLS                      15874
# MCKEE                     BLOCK 27                            0
#                           RUNNING W                           0
# MCKNIGHT                  SAND HILLS                      39882
# MONAHANS, NORTH           MONAHANS                         4991
# ORDOVICIAN                SAND HILLS                          0
# PENN UPPER                BLOCK 31                            0
# PENN.                     G. P. M.                          167
#                           UNIVERSITY WADDELL                 27
# SAN ANDRES                C-BAR                               0
#                           DELL                                0
#                           LEA                                56
# SAN ANDRES CONS.          CRAWAR                              0
# SAN ANGELO                LEA                               715
#                           SAND HILLS                       1590
# SAN ANGELO, UPPER         SAND HILLS                      26943
# TUBB                      -Y-                                 0
#                           ARMER                               0
#                           BLOCK B-21                          0
#                           RUNNING W                        1151
#                           SAND HILLS                      50800
# TUBB 4500                 CORDONA LAKE                      402
# WADDELL                   RUNNING W                        4244
#                           WADDELL                          5390
# WADDELL SD.               UNIVERSITY WADDELL                801
# WICHITA-ALBANY            RUNNING W                         720
#                           SAND HILLS                      25302
# WICHITA-ALBANY, GAS       SAND HILLS                       1420
# WOJCIK-MCELROY            SAND HILLS                        165
# WOLFCAMP                  DUNE                               26
#                           MCKEE                               0
#                           SAND HILLS                      20924
