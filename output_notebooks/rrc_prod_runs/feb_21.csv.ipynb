# %%
import pandas as pd
import datetime as dt

pd.options.display.max_columns=1000
pd.options.display.max_rows = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %run configs.ipynb

# %%
# parameter cell
file_name = 'oct_21.csv'

# %%
# Parameters
file_name = "feb_21.csv"

# %% [markdown]
# # RRC Prod

# %% [markdown]
# ## Ingest

# %%
production = pd.read_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', header = 5)

# %%
production.head()
# Out:
#   Multiple Reports Lease Type District  RRC Identifier  \
# 0              NaN        Gas       05        164066.0
# 1              NaN        Gas       7B        211352.0
# 2              NaN        Gas       7B        212409.0
# 3              NaN        Gas       7B        228695.0
# 4              NaN        Gas       7B        228926.0
#
#                Field Name                   Lease Name Gas Well ID  \
# 0        DUBOIS (BARNETT)                        MILES         1
# 1  GRANBURY, N.E. (ATOKA)                      LANGDON         2
# 2  GRANBURY, N.E. (ATOKA)  JOHN J. MILES, JR. GAS UNIT         4
# 3  GRANBURY, N.E. (ATOKA)                    LUCY UNIT         2
# 4  GRANBURY, N.E. (ATOKA)              MARSHALL, SAM A         2
#
#   Lease Total  Commingle Permit No. On Hand Beginning of Month Production  \
# 0         NaN                   NaN                          0          0
# 1         NaN                5422.0                          4          0
# 2         NaN                   NaN                          0          0
# 3         NaN                5699.0                         12          0
# 4         NaN                   NaN                          0          0
#
#   Volume  Code On Hand End of Month Formation Production Volume.1  Code.1
# 0    NaN   NaN                    0                    0      NaN     NaN
# 1    NaN   NaN                    4                    0      NaN     NaN
# 2    NaN   NaN                    0                    0      NaN     NaN
# 3    NaN   NaN                   12                  662      662     3.0
# 4    NaN   NaN                    0                    0      NaN     NaN

# %% [markdown]
# ## Transform RRC

# %% [markdown]
# ### Filter to District

# %%
#converting data field to string to handle varying schema interpreations 
#(certain months field will be interpreted as float and string depending sample rows pandas uses

production = production.loc[production['District'].astype(str).isin(['8.0', '08', '8'])]

# %%
production
# Out:
#     Multiple Reports Lease Type District  RRC Identifier          Field Name  \
# 7                NaN        Oil       08         32907.0        ARMER (TUBB)
# 8                NaN        Oil       08         20550.0        ARMER (6350)
# 9                NaN        Oil       08         45314.0        ARMER (6350)
# 10               NaN        Oil       08         48393.0        ARMER (6350)
# 11               NaN        Oil       08         49425.0        ARMER (6350)
# ..               ...        ...      ...             ...                 ...
# 470              NaN        Gas       08        160203.0  WADDELL (GRAYBURG)
# 471              NaN        Gas       08        190864.0  WADDELL (GRAYBURG)
# 472              NaN        Gas       08        190926.0  WADDELL (GRAYBURG)
# 473              NaN        Gas       08        205775.0  WADDELL (GRAYBURG)
# 474              NaN        Oil       08         20361.0   -Y-, SOUTH (TUBB)
#
#                       Lease Name Gas Well ID Lease Total  \
# 7     MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 8    MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 9                 RAYDEN MCCAMEY         NaN         NaN
# 10                    LANDLUBBER         NaN         NaN
# 11                  6 POUNDER NE         NaN         NaN
# ..                           ...         ...         ...
# 470                WADDELL, W.N.       310           NaN
# 471                WADDELL, W.N.       890           NaN
# 472                WADDELL, W.N.       293           NaN
# 473               WADDELL, W. N.      1200           NaN
# 474  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production Volume  Code  \
# 7                  7024.0                        155         27    NaN   NaN
# 8                  7024.0                         58          0    NaN   NaN
# 9                     NaN                        350        146    174   1.0
# 10                 8026.0                      1,892      7,350  7,211   0.0
# 11                 8026.0                        441      1,299  1,257   0.0
# ..                    ...                        ...        ...    ...   ...
# 470                8988.0                          0          0    NaN   NaN
# 471                8988.0                          0          0    NaN   NaN
# 472                3501.0                         16         30     30   1.0
# 473                8092.0                         16         19     25   1.0
# 474                3803.0                          0          0    NaN   NaN
#
#     On Hand End of Month Formation Production Volume.1  Code.1
# 7                    182                    0      NaN     NaN
# 8                     58                    0      NaN     NaN
# 9                    322                2,101    2,101     2.0
# 10                 2,031               28,814   28,814     2.0
# 11                   483                5,640    5,640     2.0
# ..                   ...                  ...      ...     ...
# 470                    0                    0      NaN     NaN
# 471                    0                    0      NaN     NaN
# 472                   16                   81       81     2.0
# 473                   10                  334      334     2.0
# 474                    0                    0      NaN     NaN
#
# [464 rows x 17 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 464 entries, 7 to 474
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Multiple Reports            14 non-null     object
#  1   Lease Type                  408 non-null    object
#  2   District                    464 non-null    object
#  3   RRC Identifier              464 non-null    float64
#  4   Field Name                  464 non-null    object
#  5   Lease Name                  464 non-null    object
#  6   Gas Well ID                 236 non-null    object
#  7   Lease Total                 14 non-null     object
#  8   Commingle Permit No.        275 non-null    float64
#  9   On Hand Beginning of Month  464 non-null    object
#  10  Production                  464 non-null    object
#  11  Volume                      208 non-null    object
#  12  Code                        208 non-null    float64
#  13  On Hand End of Month        464 non-null    object
#  14  Formation Production        419 non-null    object
#  15  Volume.1                    281 non-null    object
#  16  Code.1                      281 non-null    float64
# dtypes: float64(4), object(13)
# memory usage: 65.2+ KB

# %% [markdown]
# ### Clean Oil Production Columns and Convert to Int

# %%
production['Volume'] = production.loc[:,'Volume'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))
production['Volume.1'] = production.loc[:,'Volume.1'].fillna(0).apply(lambda x: int(str(x).replace(',', '')))

# %% [markdown]
# ### Rename Volume to rrc_oil_volume

# %%
production.rename(columns = {'Volume': 'rrc_oil_volume'}, inplace = True)
production.rename(columns = {'Volume.1': 'rrc_gas_volume'}, inplace = True)

# %%
production['rrc_oil_volume'].sum()
production['rrc_gas_volume'].sum()
# Out:
# 332355
# 1327661

# %% [markdown]
# ### Normalize Field and Reservoir Names with Text Cleaning

# %%
production["Normalized_Field_Name"] = production['Field Name'].dropna()\
                                                            .apply(lambda x: str(x).split('(')[0]\
                                                                                    .split(',')[0]\
                                                                                    .strip())

# %%
production["Normalized_Reservoir_Name"] = production['Field Name'].dropna()\
                                        .apply(lambda x: str(x).split('(')[-1]\
                                                               .strip().replace(')',''))

# %% [markdown]
# ### Get Date from Production File

# %%
def get_date_from_csv(filepath, col_number, row_number):
    str_date = pd.read_csv(filepath, usecols = [col_number]).iloc[row_number].values[0]
    return str_date.strip()

# %%
get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1)
# Out:
# 'Feb 2021'

# %% [markdown]
# ### Add Production Date to Production Data Frame

# %%
production.insert(0, 'Date', get_date_from_csv(f'{raw_data_folder}/rrc_prod_blackbeard/2021/{file_name}', 3, 1))

# %%
production
# Out:
#          Date Multiple Reports Lease Type District  RRC Identifier  \
# 7    Feb 2021              NaN        Oil       08         32907.0
# 8    Feb 2021              NaN        Oil       08         20550.0
# 9    Feb 2021              NaN        Oil       08         45314.0
# 10   Feb 2021              NaN        Oil       08         48393.0
# 11   Feb 2021              NaN        Oil       08         49425.0
# ..        ...              ...        ...      ...             ...
# 470  Feb 2021              NaN        Gas       08        160203.0
# 471  Feb 2021              NaN        Gas       08        190864.0
# 472  Feb 2021              NaN        Gas       08        190926.0
# 473  Feb 2021              NaN        Gas       08        205775.0
# 474  Feb 2021              NaN        Oil       08         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 7          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 8          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 9          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 10         ARMER (6350)                   LANDLUBBER         NaN         NaN
# 11         ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 470  WADDELL (GRAYBURG)                WADDELL, W.N.       310           NaN
# 471  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 472  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 473  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 474   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 7                  7024.0                        155         27
# 8                  7024.0                         58          0
# 9                     NaN                        350        146
# 10                 8026.0                      1,892      7,350
# 11                 8026.0                        441      1,299
# ..                    ...                        ...        ...
# 470                8988.0                          0          0
# 471                8988.0                          0          0
# 472                3501.0                         16         30
# 473                8092.0                         16         19
# 474                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 7                 0   NaN                  182                    0
# 8                 0   NaN                   58                    0
# 9               174   1.0                  322                2,101
# 10             7211   0.0                2,031               28,814
# 11             1257   0.0                  483                5,640
# ..              ...   ...                  ...                  ...
# 470               0   NaN                    0                    0
# 471               0   NaN                    0                    0
# 472              30   1.0                   16                   81
# 473              25   1.0                   10                  334
# 474               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name
# 7                 0     NaN                 ARMER                      TUBB
# 8                 0     NaN                 ARMER                      6350
# 9              2101     2.0                 ARMER                      6350
# 10            28814     2.0                 ARMER                      6350
# 11             5640     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 470               0     NaN               WADDELL                  GRAYBURG
# 471               0     NaN               WADDELL                  GRAYBURG
# 472              81     2.0               WADDELL                  GRAYBURG
# 473             334     2.0               WADDELL                  GRAYBURG
# 474               0     NaN                   -Y-                      TUBB
#
# [464 rows x 20 columns]

# %% [markdown]
# ### Add columns for net production to Trust

# %%
production['Net Oil Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50
production['Net Oil Sales Volume to Trust (RRC)'] = production['rrc_oil_volume'] * 0.50 * 0.75

# %%
production['Net Gas Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50
production['Net Gas Sales Volume to Trust (RRC)'] = production['rrc_gas_volume'] * 0.50 * 0.75

# %%
production
# Out:
#          Date Multiple Reports Lease Type District  RRC Identifier  \
# 7    Feb 2021              NaN        Oil       08         32907.0
# 8    Feb 2021              NaN        Oil       08         20550.0
# 9    Feb 2021              NaN        Oil       08         45314.0
# 10   Feb 2021              NaN        Oil       08         48393.0
# 11   Feb 2021              NaN        Oil       08         49425.0
# ..        ...              ...        ...      ...             ...
# 470  Feb 2021              NaN        Gas       08        160203.0
# 471  Feb 2021              NaN        Gas       08        190864.0
# 472  Feb 2021              NaN        Gas       08        190926.0
# 473  Feb 2021              NaN        Gas       08        205775.0
# 474  Feb 2021              NaN        Oil       08         20361.0
#
#              Field Name                   Lease Name Gas Well ID Lease Total  \
# 7          ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 8          ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 9          ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 10         ARMER (6350)                   LANDLUBBER         NaN         NaN
# 11         ARMER (6350)                 6 POUNDER NE         NaN         NaN
# ..                  ...                          ...         ...         ...
# 470  WADDELL (GRAYBURG)                WADDELL, W.N.       310           NaN
# 471  WADDELL (GRAYBURG)                WADDELL, W.N.       890           NaN
# 472  WADDELL (GRAYBURG)                WADDELL, W.N.       293           NaN
# 473  WADDELL (GRAYBURG)               WADDELL, W. N.      1200           NaN
# 474   -Y-, SOUTH (TUBB)  WADDELL, W.N. ET AL TR. -I-         NaN         NaN
#
#      Commingle Permit No. On Hand Beginning of Month Production  \
# 7                  7024.0                        155         27
# 8                  7024.0                         58          0
# 9                     NaN                        350        146
# 10                 8026.0                      1,892      7,350
# 11                 8026.0                        441      1,299
# ..                    ...                        ...        ...
# 470                8988.0                          0          0
# 471                8988.0                          0          0
# 472                3501.0                         16         30
# 473                8092.0                         16         19
# 474                3803.0                          0          0
#
#      rrc_oil_volume  Code On Hand End of Month Formation Production  \
# 7                 0   NaN                  182                    0
# 8                 0   NaN                   58                    0
# 9               174   1.0                  322                2,101
# 10             7211   0.0                2,031               28,814
# 11             1257   0.0                  483                5,640
# ..              ...   ...                  ...                  ...
# 470               0   NaN                    0                    0
# 471               0   NaN                    0                    0
# 472              30   1.0                   16                   81
# 473              25   1.0                   10                  334
# 474               0   NaN                    0                    0
#
#      rrc_gas_volume  Code.1 Normalized_Field_Name Normalized_Reservoir_Name  \
# 7                 0     NaN                 ARMER                      TUBB
# 8                 0     NaN                 ARMER                      6350
# 9              2101     2.0                 ARMER                      6350
# 10            28814     2.0                 ARMER                      6350
# 11             5640     2.0                 ARMER                      6350
# ..              ...     ...                   ...                       ...
# 470               0     NaN               WADDELL                  GRAYBURG
# 471               0     NaN               WADDELL                  GRAYBURG
# 472              81     2.0               WADDELL                  GRAYBURG
# 473             334     2.0               WADDELL                  GRAYBURG
# 474               0     NaN                   -Y-                      TUBB
#
#      Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 7                              0.0                                0.000
# 8                              0.0                                0.000
# 9                             87.0                               65.250
# 10                          3605.5                             2704.125
# 11                           628.5                              471.375
# ..                             ...                                  ...
# 470                            0.0                                0.000
# 471                            0.0                                0.000
# 472                           15.0                               11.250
# 473                           12.5                                9.375
# 474                            0.0                                0.000
#
#      Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 7                              0.0                                0.000
# 8                              0.0                                0.000
# 9                           1050.5                              787.875
# 10                         14407.0                            10805.250
# 11                          2820.0                             2115.000
# ..                             ...                                  ...
# 470                            0.0                                0.000
# 471                            0.0                                0.000
# 472                           40.5                               30.375
# 473                          167.0                              125.250
# 474                            0.0                                0.000
#
# [464 rows x 24 columns]

# %% [markdown]
# ### Write to File

# %%
production.to_csv(f'{processed_data_folder}/rrc_prod/{file_name}', index = False)

# %% [markdown]
# ## Aggregated EDA

# %%
production.groupby(['Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'})\
                                            .sort_values(by = 'rrc_oil_volume', ascending= False)\
                                            .head(15)
# Out:
#                        rrc_oil_volume
# Normalized_Field_Name
# SAND HILLS                     163957
# MONAHANS                        83008
# ARMER                           37980
# DUNE                            12816
# KEYSTONE                         8071
# MARSTON RANCH                    8012
# UNIVERSITY WADDELL               6925
# WADDELL                          4948
# RUNNING W                        1866
# KERMIT                           1510
# CORDONA LAKE                     1232
# LEA                               779
# SHAFTER LAKE                      734
# COWDEN                            351
# BLOCK 31                          166

# %%
production.groupby(['Normalized_Reservoir_Name', 'Normalized_Field_Name']).agg({'rrc_oil_volume': 'sum'}).sort_values(by = 'rrc_oil_volume', ascending= False).sort_index()
# Out:
#                                                  rrc_oil_volume
# Normalized_Reservoir_Name Normalized_Field_Name
# 6350                      ARMER                           37980
# 7900                      EDWARDS -04-                        0
# CLEAR FORK                LEA                               163
#                           MONAHANS                            0
#                           SAND HILLS                      35453
# CLEAR FORK 4070           SAND HILLS                         78
# CLEAR FORK, LOWER         MCKEE                               0
# CLEAR FORK, MID.          MCKEE                               0
# CLEARFORK                 MARSTON RANCH                    8012
#                           MONAHANS                        77861
#                           RM                                  0
# COLBY                     KEYSTONE                         1141
# CONSOLIDATED              KEYSTONE                         5638
# CORDONA LAKE              CORDONA LAKE                        0
# COWDEN, NORTH             COWDEN                            351
# DEV.                      CORDONA LAKE                     1091
# DEVONIAN                  CORDONA LAKE                      141
#                           UNIVERSITY WADDELL               6201
#                           WADDELL                           189
# DUNE                      DUNE                            12816
# ELLENBURGER               KERMIT                           1170
#                           SAND HILLS                       1990
#                           UNIVERSITY WADDELL                  0
# GRAYBURG                  GOLDSMITH                           0
#                           WADDELL                           331
# HOLT                      RUNNING W                          32
#                           SAND HILLS                          0
# JUDKINS                   SAND HILLS                      10989
# KERMIT                    KERMIT                            155
# MCKEE                     BLOCK 27                            0
#                           KERMIT                            185
#                           RUNNING W                           0
# MCKNIGHT                  SAND HILLS                      30445
# MONAHANS, NORTH           MONAHANS                         5147
# ORDOVICIAN                SAND HILLS                          0
# PENN UPPER                BLOCK 31                          166
# PENN.                     G. P. M.                            0
#                           UNIVERSITY WADDELL                 15
# QUEEN                     GOLDSMITH                           0
# SAN ANDRES                C-BAR                               0
#                           DELL                                0
#                           KEYSTONE                         1292
#                           LEA                                21
#                           SHAFTER LAKE                      734
# SAN ANDRES CONS.          CRAWAR                              0
# SAN ANDRES, CON.          GOLDSMITH                           0
# SAN ANGELO                LEA                               595
#                           SAND HILLS                        414
# SAN ANGELO, UPPER         SAND HILLS                      20925
# TUBB                      -Y-                                 0
#                           ARMER                               0
#                           BLOCK B-21                          0
#                           RUNNING W                          90
#                           SAND HILLS                      22532
# TUBB 4500                 CORDONA LAKE                        0
# WADDELL                   RUNNING W                         666
#                           WADDELL                          4428
# WADDELL SD.               UNIVERSITY WADDELL                709
# WICHITA-ALBANY            RUNNING W                        1078
#                           SAND HILLS                      19994
# WICHITA-ALBANY, GAS       SAND HILLS                        360
# WOJCIK-MCELROY            SAND HILLS                        266
# WOLFCAMP                  DUNE                                0
#                           MCKEE                               0
#                           SAND HILLS                      20511
# YATES                     KERMIT                              0
