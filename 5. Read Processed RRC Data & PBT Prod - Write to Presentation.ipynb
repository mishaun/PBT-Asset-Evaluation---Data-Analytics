# %%
import pandas as pd
import datetime as dt
import os
import seaborn as sns

pd.options.display.max_columns=1000
pd.options.display.max_rows = 1000

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %run configs.ipynb

# %%
def get_file_names(root_folder):
    
    file_names = list(filter(lambda x: 'DS_Store' not in x, os.listdir(root_folder)))
    return file_names

# %% [markdown]
# # Read and Concatenate RRC Prod

# %%
rrc_prod_processed_files = get_file_names(f'{processed_data_folder}/rrc_prod')

rrc_prod_processed_files
# Out:
# ['oct_21.csv',
#  'july_21.csv',
#  'june_21.csv',
#  'feb_21.csv',
#  'may_21.csv',
#  'september_21.csv',
#  'jan_21.csv',
#  'august_21.csv',
#  'march_21.csv',
#  'nov_21.csv',
#  'april_21.csv']

# %%
rrc_prod_processed_files
# Out:
# ['oct_21.csv',
#  'july_21.csv',
#  'june_21.csv',
#  'feb_21.csv',
#  'may_21.csv',
#  'september_21.csv',
#  'jan_21.csv',
#  'august_21.csv',
#  'march_21.csv',
#  'nov_21.csv',
#  'april_21.csv']

# %%
rrc_prod_dfs = [pd.read_csv(f'{processed_data_folder}/rrc_prod/{file}') for file in rrc_prod_processed_files]

# %%
rrc_prod_pres = pd.concat(rrc_prod_dfs)

# %% [markdown]
# ### Transform Dates to Datetime objects so read in properly at viz tool

# %%
rrc_prod_pres['Date'] = pd.to_datetime(rrc_prod_pres['Date'])

# %%
rrc_prod_pres.groupby('Date').sum()[['rrc_oil_volume', 'Net Oil Volume to Trust (RRC)' ]]
# Out:
#             rrc_oil_volume  Net Oil Volume to Trust (RRC)
# Date
# 2021-01-01          359609                       179804.5
# 2021-02-01          332355                       166177.5
# 2021-03-01          442912                       221456.0
# 2021-04-01          431732                       215866.0
# 2021-05-01          444124                       222062.0
# 2021-06-01          357811                       178905.5
# 2021-07-01          395910                       197955.0
# 2021-08-01          384725                       192362.5
# 2021-09-01          375220                       187610.0
# 2021-10-01          361442                       180721.0
# 2021-11-01          362868                       181434.0

# %% [markdown]
# # PBT News Prod

# %%
pbt_news_prod_files = get_file_names(f'{processed_data_folder}/pbt_news_prod/')

# %%
pbt_dfs = [pd.read_csv(f'{processed_data_folder}/pbt_news_prod/{file}') for file in pbt_news_prod_files]

# %%
pbt_news_pres = pd.concat(pbt_dfs)

# %%
pbt_news_pres["Date"].value_counts()
# Out:
# Feb 2021     2
# Sept 2021    2
# Jul 2021     2
# May 2021     2
# Aug 2021     2
# Jun 2021     2
# Oct 2021     2
# Mar 2021     2
# Apr 2021     2
# Jan 2021     2
# Name: Date, dtype: int64

# %%
pbt_news_pres["Date"].nunique()
# Out:
# 10

# %% [markdown]
# ### Transform Dates to Datetime objects so read in properly at viz tool

# %%
pbt_news_pres['Date'] = pd.to_datetime(pbt_news_pres['Date'])

# %%
pbt_news_pres
# Out:
#         Date         Property  Gross Oil Volume (PBT News)  \
# 0 2021-02-01    Waddell Ranch                        50757
# 1 2021-02-01  Texas Royalties                        19947
# 0 2021-09-01    Waddell Ranch                       120643
# 1 2021-09-01  Texas Royalties                        17123
# 0 2021-07-01    Waddell Ranch                       102735
# 1 2021-07-01  Texas Royalties                        17690
# 0 2021-05-01    Waddell Ranch                        94554
# 1 2021-05-01  Texas Royalties                        19114
# 0 2021-08-01    Waddell Ranch                       108522
# 1 2021-08-01  Texas Royalties                        17941
# 0 2021-06-01    Waddell Ranch                        90258
# 1 2021-06-01  Texas Royalties                        17820
# 0 2021-10-01    Waddell Ranch                       133626
# 1 2021-10-01  Texas Royalties                        18096
# 0 2021-03-01    Waddell Ranch                        74075
# 1 2021-03-01  Texas Royalties                        17920
# 0 2021-04-01    Waddell Ranch                        80362
# 1 2021-04-01  Texas Royalties                        16339
# 0 2021-01-01    Waddell Ranch                        61828
# 1 2021-01-01  Texas Royalties                        16211
#
#    Net Oil Volume (PBT News)  Average Oil Price  Average Gas Price  \
# 0                      38068              58.09               2.28
# 1                      17556              52.80               5.89
# 0                      90482              70.09               6.36
# 1                      15191              68.94               7.36
# 0                      77051              71.32               3.45
# 1                      15772              71.11               8.09
# 0                      70916              63.97               2.61
# 1                      16949              61.94               6.62
# 0                      81392              66.66               3.44
# 1                      15927              66.39               8.01
# 0                      67694              70.22               4.21
# 1                      15854              69.06               7.89
# 0                     100220              80.18               8.89
# 1                      16200              74.85               7.46
# 0                      55556              61.36               3.38
# 1                      15902              58.09               6.86
# 0                      60272              59.93               1.91
# 1                      14344              60.65               8.34
# 0                      46371              50.16               2.20
# 1                      13882              49.13               5.68
#
#    Gross Gas Volume (PBT News)  Net Gas Volume (PBT News)
# 0                       190570                     142928
# 1                        12461                      10948
# 0                       265108                     198831
# 1                        10650                       9442
# 0                       249359                     187019
# 1                        11870                      10570
# 0                       194689                     146017
# 1                        10523                       9333
# 0                       257857                     193393
# 1                         9871                       8757
# 0                       220120                     165090
# 1                         9894                       8797
# 0                       369258                     276944
# 1                        12056                      10787
# 0                       157614                     118211
# 1                        12115                      10598
# 0                       259608                     194706
# 1                        12869                      11276
# 0                       218264                     163653
# 1                         8828                       7560

# %% [markdown]
# ### Filtering Data to Waddell Ranch Only

# %%
pbt_news_pres = pbt_news_pres.loc[pbt_news_pres['Property']=='Waddell Ranch']

# %% [markdown]
# # EDA Before Writing to File

# %%
rrc_prod_pres['Date'].value_counts()

rrc_prod_pres.groupby('Date').agg({'RRC Identifier': 'nunique'})
# Out:
# 2021-03-01    466
# 2021-04-01    466
# 2021-02-01    464
# 2021-05-01    464
# 2021-01-01    464
# 2021-08-01    464
# 2021-06-01    460
# 2021-11-01    460
# 2021-10-01    452
# 2021-09-01    437
# 2021-07-01    385
# Name: Date, dtype: int64
#             RRC Identifier
# Date
# 2021-01-01             408
# 2021-02-01             408
# 2021-03-01             410
# 2021-04-01             411
# 2021-05-01             409
# 2021-06-01             407
# 2021-07-01             332
# 2021-08-01             409
# 2021-09-01             384
# 2021-10-01             407
# 2021-11-01             406

# %%
rrc_prod_pres.head()
rrc_prod_pres['District'].value_counts()
rrc_prod_pres.info()
# Out:
#         Date Multiple Reports Lease Type  District  RRC Identifier  \
# 0 2021-10-01              NaN        Oil       8.0         32907.0
# 1 2021-10-01              NaN        Oil       8.0         20550.0
# 2 2021-10-01              NaN        Oil       8.0         45314.0
# 3 2021-10-01                Y        Oil       8.0         48393.0
# 4 2021-10-01              NaN        Oil       8.0         49425.0
#
#      Field Name                   Lease Name Gas Well ID Lease Total  \
# 0  ARMER (TUBB)   MCCAMEY, G. B. "A" (NCT-B)         NaN         NaN
# 1  ARMER (6350)  MCCAMEY, G. B., -A- /NCT-A/         NaN         NaN
# 2  ARMER (6350)               RAYDEN MCCAMEY         NaN         NaN
# 3  ARMER (6350)                   LANDLUBBER         NaN         NaN
# 4  ARMER (6350)                 6 POUNDER NE         NaN         NaN
#
#    Commingle Permit No. On Hand Beginning of Month Production  rrc_oil_volume  \
# 0                7024.0                        140         26               0
# 1                7024.0                         18          0               0
# 2                   NaN                        261         87             183
# 3                8026.0                      1,721      7,857            8126
# 4                8026.0                        507        870            1184
#
#    Code On Hand End of Month Formation Production  rrc_gas_volume  Code.1  \
# 0   NaN                  166                    0               0     NaN
# 1   NaN                   18                    0               0     NaN
# 2   1.0                  165                1,699            1699     2.0
# 3   0.0                1,452               19,723           19723     2.0
# 4   0.0                  193                3,832            3832     2.0
#
#   Normalized_Field_Name Normalized_Reservoir_Name  \
# 0                 ARMER                      TUBB
# 1                 ARMER                      6350
# 2                 ARMER                      6350
# 3                 ARMER                      6350
# 4                 ARMER                      6350
#
#    Net Oil Volume to Trust (RRC)  Net Oil Sales Volume to Trust (RRC)  \
# 0                            0.0                                0.000
# 1                            0.0                                0.000
# 2                           91.5                               68.625
# 3                         4063.0                             3047.250
# 4                          592.0                              444.000
#
#    Net Gas Volume to Trust (RRC)  Net Gas Sales Volume to Trust (RRC)
# 0                            0.0                                0.000
# 1                            0.0                                0.000
# 2                          849.5                              637.125
# 3                         9861.5                             7396.125
# 4                         1916.0                             1437.000
# 8.0    4982
# Name: District, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4982 entries, 0 to 465
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 4982 non-null   datetime64[ns]
#  1   Multiple Reports                     717 non-null    object
#  2   Lease Type                           4391 non-null   object
#  3   District                             4982 non-null   float64
#  4   RRC Identifier                       4982 non-null   float64
#  5   Field Name                           4982 non-null   object
#  6   Lease Name                           4982 non-null   object
#  7   Gas Well ID                          2507 non-null   object
#  8   Lease Total                          148 non-null    object
#  9   Commingle Permit No.                 2990 non-null   float64
#  10  On Hand Beginning of Month           4776 non-null   object
#  11  Production                           4982 non-null   object
#  12  rrc_oil_volume                       4982 non-null   int64
#  13  Code                                 2204 non-null   float64
#  14  On Hand End of Month                 4982 non-null   object
#  15  Formation Production                 4484 non-null   object
#  16  rrc_gas_volume                       4982 non-null   int64
#  17  Code.1                               2844 non-null   float64
#  18  Normalized_Field_Name                4982 non-null   object
#  19  Normalized_Reservoir_Name            4982 non-null   object
#  20  Net Oil Volume to Trust (RRC)        4982 non-null   float64
#  21  Net Oil Sales Volume to Trust (RRC)  4982 non-null   float64
#  22  Net Gas Volume to Trust (RRC)        4982 non-null   float64
#  23  Net Gas Sales Volume to Trust (RRC)  4982 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(12)
# memory usage: 973.0+ KB

# %%
count_date_well = rrc_prod_pres.groupby(['Date', 'RRC Identifier']).agg({'rrc_oil_volume': 'count'})

# %%
count_date_well[count_date_well['rrc_oil_volume']>1]
# Out:
#                            rrc_oil_volume
# Date       RRC Identifier
# 2021-01-01 1224.0                       5
#            5263.0                       7
#            5283.0                       3
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      4
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-02-01 1224.0                       5
#            5263.0                       7
#            5283.0                       3
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      4
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-03-01 1224.0                       5
#            5263.0                       7
#            5283.0                       3
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      4
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-04-01 1224.0                       5
#            5263.0                       7
#            5283.0                       3
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      3
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-05-01 1224.0                       5
#            5263.0                       7
#            5283.0                       3
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      3
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-06-01 1224.0                       5
#            5263.0                       7
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      3
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-07-01 1224.0                       5
#            5263.0                       7
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      3
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-08-01 1224.0                       5
#            5263.0                       7
#            5283.0                       3
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      3
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-09-01 1224.0                       5
#            5263.0                       7
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      3
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-10-01 1224.0                       5
#            5263.0                       7
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            18745.0                      8
#            20914.0                      3
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3
# 2021-11-01 1224.0                       5
#            5263.0                       7
#            5294.0                       8
#            7155.0                       5
#            12207.0                      4
#            12508.0                      4
#            15266.0                      9
#            18745.0                      8
#            20914.0                      4
#            37331.0                      4
#            45532.0                      3
#            48213.0                      3
#            53009.0                      3

# %% [markdown]
# # Write Tables to File

# %%
pbt_news_pres.to_csv(f'{presentation_data_folder}/pbt_news_prod/pbt_news_prod.csv', index = False)

# %%
rrc_prod_pres.to_csv(f'{presentation_data_folder}/rrc_prod_blackbeard/rrc_prod.csv', index = False)
